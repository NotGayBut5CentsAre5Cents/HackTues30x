# %%
import pickle

with open('./articles.p', 'rb') as fp:
    heds, contents = pickle.load(fp)

# %%
from collections import Counter
from itertools import chain

# %%
import re
import nltk
all_text = " ".join(heds + contents).replace(".", " ")
tokenized_words = nltk.word_tokenize(all_text)
vocabcount = Counter(word for word in tokenized_words)
vocab = map(lambda x: x[0], sorted(vocabcount.items(), key=lambda x: -x[1]))

# %%
len(vocabcount)
# Out:
# 14099

# %%
glove_vec_size = 100
fname = 'glove.6B.%d.txt'%glove_vec_size
import os
start = 2

# %%
word2idx = dict((word, i+start) for i,word in enumerate(vocab))

# %%
word2idx['<empty>'] = 0
word2idx['<eos>'] = 1

# %%
idx2word = dict((idx,word) for word,idx in word2idx.items())

# %%
import os
glove_path = r'./data/glove.6B/glove.6B.100d.txt'

# %%
glove_word_count = !wc -l {glove_path}

# %%
glove_word_count = int(glove_word_count[0].split(" ")[0])

# %%
glove_word_count
# Out:
# 400000

# %%
print(glove_word_count)
# Out:
# 400000

# %%
import numpy as np
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_word_count, 100))
with open(glove_path, 'r') as fp:
    i = 0
    for l in fp:
        l = l.strip().split() #split vector values
        word = l[0]
        glove_index_dict[word] = i
        slice = map(float,l[1:])
        glove_embedding_weights[i,:] = list(slice)
        i += 1

# %%
glove_embedding_weights
# Out:
# array([[-0.038194, -0.24487 ,  0.72812 , ..., -0.1459  ,  0.8278  ,
#          0.27062 ],
#        [-0.10767 ,  0.11053 ,  0.59812 , ..., -0.83155 ,  0.45293 ,
#          0.082577],
#        [-0.33979 ,  0.20941 ,  0.46348 , ..., -0.23394 ,  0.47298 ,
#         -0.028803],
#        ...,
#        [ 0.36088 , -0.16919 , -0.32704 , ...,  0.27139 , -0.29188 ,
#          0.16109 ],
#        [-0.10461 , -0.5047  , -0.49331 , ...,  0.42527 , -0.5125  ,
#         -0.17054 ],
#        [ 0.28365 , -0.6263  , -0.44351 , ...,  0.43678 , -0.82607 ,
#         -0.15701 ]])

# %%
for w,i in glove_index_dict.items():
    l = w.lower()
    if w not in glove_index_dict:
        glove_index_dict[l] = i

# %%
glove_index_dict
# Out:
# {'the': 0,
#  ',': 1,
#  '.': 2,
#  'of': 3,
#  'to': 4,
#  'and': 5,
#  'in': 6,
#  'a': 7,
#  '"': 8,
#  "'s": 9,
#  'for': 10,
#  '-': 11,
#  'that': 12,
#  'on': 13,
#  'is': 14,
#  'was': 15,
#  'said': 16,
#  'with': 17,
#  'he': 18,
#  'as': 19,
#  'it': 20,
#  'by': 21,
#  'at': 22,
#  '(': 23,
#  ')': 24,
#  'from': 25,
#  'his': 26,
#  "''": 27,
#  '``': 28,
#  'an': 29,
#  'be': 30,
#  'has': 31,
#  'are': 32,
#  'have': 33,
#  'but': 34,
#  'were': 35,
#  'not': 36,
#  'this': 37,
#  'who': 38,
#  'they': 39,
#  'had': 40,
#  'i': 41,
#  'which': 42,
#  'will': 43,
#  'their': 44,
#  ':': 45,
#  'or': 46,
#  'its': 47,
#  'one': 48,
#  'after': 49,
#  'new': 50,
#  'been': 51,
#  'also': 52,
#  'we': 53,
#  'would': 54,
#  'two': 55,
#  'more': 56,
#  "'": 57,
#  'first': 58,
#  'about': 59,
#  'up': 60,
#  'when': 61,
#  'year': 62,
#  'there': 63,
#  'all': 64,
#  '--': 65,
#  'out': 66,
#  'she': 67,
#  'other': 68,
#  'people': 69,
#  "n't": 70,
#  'her': 71,
#  'percent': 72,
#  'than': 73,
#  'over': 74,
#  'into': 75,
#  'last': 76,
#  'some': 77,
#  'government': 78,
#  'time': 79,
#  '$': 80,
#  'you': 81,
#  'years': 82,
#  'if': 83,
#  'no': 84,
#  'world': 85,
#  'can': 86,
#  'three': 87,
#  'do': 88,
#  ';': 89,
#  'president': 90,
#  'only': 91,
#  'state': 92,
#  'million': 93,
#  'could': 94,
#  'us': 95,
#  'most': 96,
#  '_': 97,
#  'against': 98,
#  'u.s.': 99,
#  'so': 100,
#  'them': 101,
#  'what': 102,
#  'him': 103,
#  'united': 104,
#  'during': 105,
#  'before': 106,
#  'may': 107,
#  'since': 108,
#  'many': 109,
#  'while': 110,
#  'where': 111,
#  'states': 112,
#  'because': 113,
#  'now': 114,
#  'city': 115,
#  'made': 116,
#  'like': 117,
#  'between': 118,
#  'did': 119,
#  'just': 120,
#  'national': 121,
#  'day': 122,
#  'country': 123,
#  'under': 124,
#  'such': 125,
#  'second': 126,
#  'then': 127,
#  'company': 128,
#  'group': 129,
#  'any': 130,
#  'through': 131,
#  'china': 132,
#  'four': 133,
#  'being': 134,
#  'down': 135,
#  'war': 136,
#  'back': 137,
#  'off': 138,
#  'south': 139,
#  'american': 140,
#  'minister': 141,
#  'police': 142,
#  'well': 143,
#  'including': 144,
#  'team': 145,
#  'international': 146,
#  'week': 147,
#  'officials': 148,
#  'still': 149,
#  'both': 150,
#  'even': 151,
#  'high': 152,
#  'part': 153,
#  'told': 154,
#  'those': 155,
#  'end': 156,
#  'former': 157,
#  'these': 158,
#  'make': 159,
#  'billion': 160,
#  'work': 161,
#  'our': 162,
#  'home': 163,
#  'school': 164,
#  'party': 165,
#  'house': 166,
#  'old': 167,
#  'later': 168,
#  'get': 169,
#  'another': 170,
#  'tuesday': 171,
#  'news': 172,
#  'long': 173,
#  'five': 174,
#  'called': 175,
#  '1': 176,
#  'wednesday': 177,
#  'military': 178,
#  'way': 179,
#  'used': 180,
#  'much': 181,
#  'next': 182,
#  'monday': 183,
#  'thursday': 184,
#  'friday': 185,
#  'game': 186,
#  'here': 187,
#  '?': 188,
#  'should': 189,
#  'take': 190,
#  'very': 191,
#  'my': 192,
#  'north': 193,
#  'security': 194,
#  'season': 195,
#  'york': 196,
#  'how': 197,
#  'public': 198,
#  'early': 199,
#  'according': 200,
#  'several': 201,
#  'court': 202,
#  'say': 203,
#  'around': 204,
#  'foreign': 205,
#  '10': 206,
#  'until': 207,
#  'set': 208,
#  'political': 209,
#  'says': 210,
#  'market': 211,
#  'however': 212,
#  'family': 213,
#  'life': 214,
#  'same': 215,
#  'general': 216,
#  '–': 217,
#  'left': 218,
#  'good': 219,
#  'top': 220,
#  'university': 221,
#  'going': 222,
#  'number': 223,
#  'major': 224,
#  'known': 225,
#  'points': 226,
#  'won': 227,
#  'six': 228,
#  'month': 229,
#  'dollars': 230,
#  'bank': 231,
#  '2': 232,
#  'iraq': 233,
#  'use': 234,
#  'members': 235,
#  'each': 236,
#  'area': 237,
#  'found': 238,
#  'official': 239,
#  'sunday': 240,
#  'place': 241,
#  'go': 242,
#  'based': 243,
#  'among': 244,
#  'third': 245,
#  'times': 246,
#  'took': 247,
#  'right': 248,
#  'days': 249,
#  'local': 250,
#  'economic': 251,
#  'countries': 252,
#  'see': 253,
#  'best': 254,
#  'report': 255,
#  'killed': 256,
#  'held': 257,
#  'business': 258,
#  'west': 259,
#  'does': 260,
#  'own': 261,
#  '%': 262,
#  'came': 263,
#  'law': 264,
#  'months': 265,
#  'women': 266,
#  "'re": 267,
#  'power': 268,
#  'think': 269,
#  'service': 270,
#  'children': 271,
#  'bush': 272,
#  'show': 273,
#  '/': 274,
#  'help': 275,
#  'chief': 276,
#  'saturday': 277,
#  'system': 278,
#  'john': 279,
#  'support': 280,
#  'series': 281,
#  'play': 282,
#  'office': 283,
#  'following': 284,
#  'me': 285,
#  'meeting': 286,
#  'expected': 287,
#  'late': 288,
#  'washington': 289,
#  'games': 290,
#  'european': 291,
#  'league': 292,
#  'reported': 293,
#  'final': 294,
#  'added': 295,
#  'without': 296,
#  'british': 297,
#  'white': 298,
#  'history': 299,
#  'man': 300,
#  'men': 301,
#  'became': 302,
#  'want': 303,
#  'march': 304,
#  'case': 305,
#  'few': 306,
#  'run': 307,
#  'money': 308,
#  'began': 309,
#  'open': 310,
#  'name': 311,
#  'trade': 312,
#  'center': 313,
#  '3': 314,
#  'israel': 315,
#  'oil': 316,
#  'too': 317,
#  'al': 318,
#  'film': 319,
#  'win': 320,
#  'led': 321,
#  'east': 322,
#  'central': 323,
#  '20': 324,
#  'air': 325,
#  'come': 326,
#  'chinese': 327,
#  'town': 328,
#  'leader': 329,
#  'army': 330,
#  'line': 331,
#  'never': 332,
#  'little': 333,
#  'played': 334,
#  'prime': 335,
#  'death': 336,
#  'companies': 337,
#  'least': 338,
#  'put': 339,
#  'forces': 340,
#  'past': 341,
#  'de': 342,
#  'half': 343,
#  'june': 344,
#  'saying': 345,
#  'know': 346,
#  'federal': 347,
#  'french': 348,
#  'peace': 349,
#  'earlier': 350,
#  'capital': 351,
#  'force': 352,
#  'great': 353,
#  'union': 354,
#  'near': 355,
#  'released': 356,
#  'small': 357,
#  'department': 358,
#  'every': 359,
#  'health': 360,
#  'japan': 361,
#  'head': 362,
#  'ago': 363,
#  'night': 364,
#  'big': 365,
#  'cup': 366,
#  'election': 367,
#  'region': 368,
#  'director': 369,
#  'talks': 370,
#  'program': 371,
#  'far': 372,
#  'today': 373,
#  'statement': 374,
#  'july': 375,
#  'although': 376,
#  'district': 377,
#  'again': 378,
#  'born': 379,
#  'development': 380,
#  'leaders': 381,
#  'council': 382,
#  'close': 383,
#  'record': 384,
#  'along': 385,
#  'county': 386,
#  'france': 387,
#  'went': 388,
#  'point': 389,
#  'must': 390,
#  'spokesman': 391,
#  'your': 392,
#  'member': 393,
#  'plan': 394,
#  'financial': 395,
#  'april': 396,
#  'recent': 397,
#  'campaign': 398,
#  'become': 399,
#  'troops': 400,
#  'whether': 401,
#  'lost': 402,
#  'music': 403,
#  '15': 404,
#  'got': 405,
#  'israeli': 406,
#  '30': 407,
#  'need': 408,
#  '4': 409,
#  'lead': 410,
#  'already': 411,
#  'russia': 412,
#  'though': 413,
#  'might': 414,
#  'free': 415,
#  'hit': 416,
#  'rights': 417,
#  '11': 418,
#  'information': 419,
#  'away': 420,
#  '12': 421,
#  '5': 422,
#  'others': 423,
#  'control': 424,
#  'within': 425,
#  'large': 426,
#  'economy': 427,
#  'press': 428,
#  'agency': 429,
#  'water': 430,
#  'died': 431,
#  'career': 432,
#  'making': 433,
#  '...': 434,
#  'deal': 435,
#  'attack': 436,
#  'side': 437,
#  'seven': 438,
#  'better': 439,
#  'less': 440,
#  'september': 441,
#  'once': 442,
#  'clinton': 443,
#  'main': 444,
#  'due': 445,
#  'committee': 446,
#  'building': 447,
#  'conference': 448,
#  'club': 449,
#  'january': 450,
#  'decision': 451,
#  'stock': 452,
#  'america': 453,
#  'given': 454,
#  'give': 455,
#  'often': 456,
#  'announced': 457,
#  'television': 458,
#  'industry': 459,
#  'order': 460,
#  'young': 461,
#  "'ve": 462,
#  'palestinian': 463,
#  'age': 464,
#  'start': 465,
#  'administration': 466,
#  'russian': 467,
#  'prices': 468,
#  'round': 469,
#  'december': 470,
#  'nations': 471,
#  "'m": 472,
#  'human': 473,
#  'india': 474,
#  'defense': 475,
#  'asked': 476,
#  'total': 477,
#  'october': 478,
#  'players': 479,
#  'bill': 480,
#  'important': 481,
#  'southern': 482,
#  'move': 483,
#  'fire': 484,
#  'population': 485,
#  'rose': 486,
#  'november': 487,
#  'include': 488,
#  'further': 489,
#  'nuclear': 490,
#  'street': 491,
#  'taken': 492,
#  'media': 493,
#  'different': 494,
#  'issue': 495,
#  'received': 496,
#  'secretary': 497,
#  'return': 498,
#  'college': 499,
#  'working': 500,
#  'community': 501,
#  'eight': 502,
#  'groups': 503,
#  'despite': 504,
#  'level': 505,
#  'largest': 506,
#  'whose': 507,
#  'attacks': 508,
#  'germany': 509,
#  'august': 510,
#  'change': 511,
#  'church': 512,
#  'nation': 513,
#  'german': 514,
#  'station': 515,
#  'london': 516,
#  'weeks': 517,
#  'having': 518,
#  '18': 519,
#  'research': 520,
#  'black': 521,
#  'services': 522,
#  'story': 523,
#  '6': 524,
#  'europe': 525,
#  'sales': 526,
#  'policy': 527,
#  'visit': 528,
#  'northern': 529,
#  'lot': 530,
#  'across': 531,
#  'per': 532,
#  'current': 533,
#  'board': 534,
#  'football': 535,
#  'ministry': 536,
#  'workers': 537,
#  'vote': 538,
#  'book': 539,
#  'fell': 540,
#  'seen': 541,
#  'role': 542,
#  'students': 543,
#  'shares': 544,
#  'iran': 545,
#  'process': 546,
#  'agreement': 547,
#  'quarter': 548,
#  'full': 549,
#  'match': 550,
#  'started': 551,
#  'growth': 552,
#  'yet': 553,
#  'moved': 554,
#  'possible': 555,
#  'western': 556,
#  'special': 557,
#  '100': 558,
#  'plans': 559,
#  'interest': 560,
#  'behind': 561,
#  'strong': 562,
#  'england': 563,
#  'named': 564,
#  'food': 565,
#  'period': 566,
#  'real': 567,
#  'authorities': 568,
#  'car': 569,
#  'term': 570,
#  'rate': 571,
#  'race': 572,
#  'nearly': 573,
#  'korea': 574,
#  'enough': 575,
#  'site': 576,
#  'opposition': 577,
#  'keep': 578,
#  '25': 579,
#  'call': 580,
#  'future': 581,
#  'taking': 582,
#  'island': 583,
#  '2008': 584,
#  '2006': 585,
#  'road': 586,
#  'outside': 587,
#  'really': 588,
#  'century': 589,
#  'democratic': 590,
#  'almost': 591,
#  'single': 592,
#  'share': 593,
#  'leading': 594,
#  'trying': 595,
#  'find': 596,
#  'album': 597,
#  'senior': 598,
#  'minutes': 599,
#  'together': 600,
#  'congress': 601,
#  'index': 602,
#  'australia': 603,
#  'results': 604,
#  'hard': 605,
#  'hours': 606,
#  'land': 607,
#  'action': 608,
#  'higher': 609,
#  'field': 610,
#  'cut': 611,
#  'coach': 612,
#  'elections': 613,
#  'san': 614,
#  'issues': 615,
#  'executive': 616,
#  'february': 617,
#  'production': 618,
#  'areas': 619,
#  'river': 620,
#  'face': 621,
#  'using': 622,
#  'japanese': 623,
#  'province': 624,
#  'park': 625,
#  'price': 626,
#  'commission': 627,
#  'california': 628,
#  'father': 629,
#  'son': 630,
#  'education': 631,
#  '7': 632,
#  'village': 633,
#  'energy': 634,
#  'shot': 635,
#  'short': 636,
#  'africa': 637,
#  'key': 638,
#  'red': 639,
#  'association': 640,
#  'average': 641,
#  'pay': 642,
#  'exchange': 643,
#  'eu': 644,
#  'something': 645,
#  'gave': 646,
#  'likely': 647,
#  'player': 648,
#  'george': 649,
#  '2007': 650,
#  'victory': 651,
#  '8': 652,
#  'low': 653,
#  'things': 654,
#  '2010': 655,
#  'pakistan': 656,
#  '14': 657,
#  'post': 658,
#  'social': 659,
#  'continue': 660,
#  'ever': 661,
#  'look': 662,
#  'chairman': 663,
#  'job': 664,
#  '2000': 665,
#  'soldiers': 666,
#  'able': 667,
#  'parliament': 668,
#  'front': 669,
#  'himself': 670,
#  'problems': 671,
#  'private': 672,
#  'lower': 673,
#  'list': 674,
#  'built': 675,
#  '13': 676,
#  'efforts': 677,
#  'dollar': 678,
#  'miles': 679,
#  'included': 680,
#  'radio': 681,
#  'live': 682,
#  'form': 683,
#  'david': 684,
#  'african': 685,
#  'increase': 686,
#  'reports': 687,
#  'sent': 688,
#  'fourth': 689,
#  'always': 690,
#  'king': 691,
#  '50': 692,
#  'tax': 693,
#  'taiwan': 694,
#  'britain': 695,
#  '16': 696,
#  'playing': 697,
#  'title': 698,
#  'middle': 699,
#  'meet': 700,
#  'global': 701,
#  'wife': 702,
#  '2009': 703,
#  'position': 704,
#  'located': 705,
#  'clear': 706,
#  'ahead': 707,
#  '2004': 708,
#  '2005': 709,
#  'iraqi': 710,
#  'english': 711,
#  'result': 712,
#  'release': 713,
#  'violence': 714,
#  'goal': 715,
#  'project': 716,
#  'closed': 717,
#  'border': 718,
#  'body': 719,
#  'soon': 720,
#  'crisis': 721,
#  'division': 722,
#  '&amp;': 723,
#  'served': 724,
#  'tour': 725,
#  'hospital': 726,
#  'kong': 727,
#  'test': 728,
#  'hong': 729,
#  'u.n.': 730,
#  'inc.': 731,
#  'technology': 732,
#  'believe': 733,
#  'organization': 734,
#  'published': 735,
#  'weapons': 736,
#  'agreed': 737,
#  'why': 738,
#  'nine': 739,
#  'summer': 740,
#  'wanted': 741,
#  'republican': 742,
#  'act': 743,
#  'recently': 744,
#  'texas': 745,
#  'course': 746,
#  'problem': 747,
#  'senate': 748,
#  'medical': 749,
#  'un': 750,
#  'done': 751,
#  'reached': 752,
#  'star': 753,
#  'continued': 754,
#  'investors': 755,
#  'living': 756,
#  'care': 757,
#  'signed': 758,
#  '17': 759,
#  'art': 760,
#  'provide': 761,
#  'worked': 762,
#  'presidential': 763,
#  'gold': 764,
#  'obama': 765,
#  'morning': 766,
#  'dead': 767,
#  'opened': 768,
#  "'ll": 769,
#  'event': 770,
#  'previous': 771,
#  'cost': 772,
#  'instead': 773,
#  'canada': 774,
#  'band': 775,
#  'teams': 776,
#  'daily': 777,
#  '2001': 778,
#  'available': 779,
#  'drug': 780,
#  'coming': 781,
#  '2003': 782,
#  'investment': 783,
#  '’s': 784,
#  'michael': 785,
#  'civil': 786,
#  'woman': 787,
#  'training': 788,
#  'appeared': 789,
#  '9': 790,
#  'involved': 791,
#  'indian': 792,
#  'similar': 793,
#  'situation': 794,
#  '24': 795,
#  'los': 796,
#  'running': 797,
#  'fighting': 798,
#  'mark': 799,
#  '40': 800,
#  'trial': 801,
#  'hold': 802,
#  'australian': 803,
#  'thought': 804,
#  '!': 805,
#  'study': 806,
#  'fall': 807,
#  'mother': 808,
#  'met': 809,
#  'relations': 810,
#  'anti': 811,
#  '2002': 812,
#  'song': 813,
#  'popular': 814,
#  'base': 815,
#  'tv': 816,
#  'ground': 817,
#  'markets': 818,
#  'ii': 819,
#  'newspaper': 820,
#  'staff': 821,
#  'saw': 822,
#  'hand': 823,
#  'hope': 824,
#  'operations': 825,
#  'pressure': 826,
#  'americans': 827,
#  'eastern': 828,
#  'st.': 829,
#  'legal': 830,
#  'asia': 831,
#  'budget': 832,
#  'returned': 833,
#  'considered': 834,
#  'love': 835,
#  'wrote': 836,
#  'stop': 837,
#  'fight': 838,
#  'currently': 839,
#  'charges': 840,
#  'try': 841,
#  'aid': 842,
#  'ended': 843,
#  'management': 844,
#  'brought': 845,
#  'cases': 846,
#  'decided': 847,
#  'failed': 848,
#  'network': 849,
#  'works': 850,
#  'gas': 851,
#  'turned': 852,
#  'fact': 853,
#  'vice': 854,
#  'ca': 855,
#  'mexico': 856,
#  'trading': 857,
#  'especially': 858,
#  'reporters': 859,
#  'afghanistan': 860,
#  'common': 861,
#  'looking': 862,
#  'space': 863,
#  'rates': 864,
#  'manager': 865,
#  'loss': 866,
#  '2011': 867,
#  'justice': 868,
#  'thousands': 869,
#  'james': 870,
#  'rather': 871,
#  'fund': 872,
#  'thing': 873,
#  'republic': 874,
#  'opening': 875,
#  'accused': 876,
#  'winning': 877,
#  'scored': 878,
#  'championship': 879,
#  'example': 880,
#  'getting': 881,
#  'biggest': 882,
#  'performance': 883,
#  'sports': 884,
#  '1998': 885,
#  'let': 886,
#  'allowed': 887,
#  'schools': 888,
#  'means': 889,
#  'turn': 890,
#  'leave': 891,
#  'no.': 892,
#  'robert': 893,
#  'personal': 894,
#  'stocks': 895,
#  'showed': 896,
#  'light': 897,
#  'arrested': 898,
#  'person': 899,
#  'either': 900,
#  'offer': 901,
#  'majority': 902,
#  'battle': 903,
#  '19': 904,
#  'class': 905,
#  'evidence': 906,
#  'makes': 907,
#  'society': 908,
#  'products': 909,
#  'regional': 910,
#  'needed': 911,
#  'stage': 912,
#  'am': 913,
#  'doing': 914,
#  'families': 915,
#  'construction': 916,
#  'various': 917,
#  '1996': 918,
#  'sold': 919,
#  'independent': 920,
#  'kind': 921,
#  'airport': 922,
#  'paul': 923,
#  'judge': 924,
#  'internet': 925,
#  'movement': 926,
#  'room': 927,
#  'followed': 928,
#  'original': 929,
#  'angeles': 930,
#  'italy': 931,
#  '`': 932,
#  'data': 933,
#  'comes': 934,
#  'parties': 935,
#  'nothing': 936,
#  'sea': 937,
#  'bring': 938,
#  '2012': 939,
#  'annual': 940,
#  'officer': 941,
#  'beijing': 942,
#  'present': 943,
#  'remain': 944,
#  'nato': 945,
#  '1999': 946,
#  '22': 947,
#  'remains': 948,
#  'allow': 949,
#  'florida': 950,
#  'computer': 951,
#  '21': 952,
#  'contract': 953,
#  'coast': 954,
#  'created': 955,
#  'demand': 956,
#  'operation': 957,
#  'events': 958,
#  'islamic': 959,
#  'beat': 960,
#  'analysts': 961,
#  'interview': 962,
#  'helped': 963,
#  'child': 964,
#  'probably': 965,
#  'spent': 966,
#  'asian': 967,
#  'effort': 968,
#  'cooperation': 969,
#  'shows': 970,
#  'calls': 971,
#  'investigation': 972,
#  'lives': 973,
#  'video': 974,
#  'yen': 975,
#  'runs': 976,
#  'tried': 977,
#  'bad': 978,
#  'described': 979,
#  '1994': 980,
#  'toward': 981,
#  'written': 982,
#  'throughout': 983,
#  'established': 984,
#  'mission': 985,
#  'associated': 986,
#  'buy': 987,
#  'growing': 988,
#  'green': 989,
#  'forward': 990,
#  'competition': 991,
#  'poor': 992,
#  'latest': 993,
#  'banks': 994,
#  'question': 995,
#  '1997': 996,
#  'prison': 997,
#  'feel': 998,
#  'attention': 999,
#  ...}

# %%
glove_word_count
# Out:
# 400000

# %%
np.random.seed(42)
shape = (glove_word_count, glove_vec_size)
scale = glove_embedding_weights.std()
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

c = 0
for i in range(len(vocabcount)):
    word = idx2word[i]
    glove_idx = glove_index_dict.get(word) or glove_index_dict.get(word.lower())
    if glove_idx is not None:
        embedding[i,:] = glove_embedding_weights[glove_idx,:]
        c+=1
    else:
        print(word)
c
# Out:
# <empty>
# <eos>
# 5bn
# ВЈ1
# 4bn
# 8bn
# 6bn
# 7bn
# 9bn
# ВЈ2
# ВЈ3
# 11bn
# ВЈ4
# ВЈ5
# 27bn
# 20bn
# 16bn
# Phytopharm
# ВЈ800m
# ВЈ7
# 75bn
# 300p
# 280bn
# ВЈ10
# 35bn
# ВЈ8
# 180bn
# Krivorizhstal
# ODPM
# Apacs
# ВЈ6
# ВЈ1bn
# rate-setting
# 45bn
# with-profits
# 'to
# 25bn
# Diemont
# Agroflora
# ВЈ9
# 850m
# like-for-like
# 19bn
# 30bn
# Easymobile
# ВЈ200m
# Toshitsune
# Contrack
# Illva
# back-tax
# 13bn
# anti-racketeering
# 12bn
# ВЈ21
# 96bn
# 17bn
# 14bn
# 375m
# 200bn
# 23bn
# business-based
# ВЈ10bn
# Paulsmeier
# post-Christmas
# 37bn
# ex-Yukos
# Mohd-Saaid
# 'may
# ex-boss
# 28bn
# sell-offs
# ВЈ42m
# ВЈ194m
# 168m
# 206bn
# US-German
# ERAA
# 136m
# ВЈ14
# ВЈ350m
# 412bn
# ВЈ100m
# 89bn
# car-making
# 68m
# renationalise
# 91m
# Irancell
# 427bn
# October-to-December
# ВЈ1m
# ВЈ424m
# 80bn
# 100bn
# Jinshajiang
# buy-to-let
# ВЈ6bn
# technology-dominated
# ВЈ5bn
# Prettejohn
# ВЈ100
# split-capital
# ВЈ52m
# 15bn
# AEFA
# ВЈ14bn
# 60bn
# 'put
# Cochilco
# Fiat-GM
# 515m
# 'strong
# post-Enron
# post-quake
# 54m
# 368bn
# year-earlier
# 36bn
# worse-than-expected
# ВЈ75m
# ВЈ160m
# 97bn
# Egelton
# ВЈ155bn
# ВЈ170m
# Frank-Juergen
# seasonally-adjusted
# 32bn
# ВЈ16
# Charcote
# larger-than-expected
# 04bn
# better-than-expected
# ВЈ15
# ВЈ24
# baby-boom
# gigajoule
# re-listing
# 05bn
# ВЈ198m
# ВЈ190m
# Bewlay
# ВЈ415m
# beer-flavoured
# 950m
# pre-payment
# Lukashov
# 160bn
# ВЈ53
# 41bn
# ВЈ230bn
# bid-rigging
# 984m
# 99bn
# German-US
# ex-Columbia
# 47bn
# Otoku
# ВЈ38
# 33bn
# Gibraltar-based
# 630m
# politically-motivated
# Inoni
# 87bn
# 55bn
# Lilliu
# ВЈ400m
# ВЈ13bn
# Frankfurt-based
# 48bn
# 'wait
# anti-Aids
# Itrec
# Addink
# former-President
# Aishwariya
# 65bn
# Haji-Ioannou
# with-profit
# With-profits
# ВЈ138m
# Hemington
# 300-shareholder
# capitalisations
# ВЈ374m
# 07bn
# ВЈ558m
# 331bn
# 39m
# ВЈ21m
# 75p
# desmoteplase
# 'chip
# card-not-present
# Sudell
# ВЈ26
# ВЈ36
# ex-finance
# Monica-based
# Activison
# X-Box
# slower-than-expected
# trade-driven
# 18bn
# nano-technology
# worst-affected
# tsunami-affected
# ВЈ398m
# 768m
# Chaiyasoot
# 660m
# London-Frankfurt
# shake-out
# nose-diving
# ВЈ1,200
# Singapore-listed
# 54bn
# significantly-improved
# 440,700
# 22bn
# market-set
# widely-predicted
# over-abrupt
# ВЈ19
# Khurmala
# Himrin
# Alcobev
# ВЈ3bn
# ВЈ25
# Shipside
# ВЈ600
# ВЈ190,329
# ВЈ189,733
# 377bn
# ВЈ26m
# Gorur
# export-driven
# Troeber
# 38am
# ВЈ28
# Alfa-Eco
# Boix-Vives
# Management-Chicago
# year-ago
# Douglas-Westwood
# tsunami-hit
# ВЈ82
# Macaefa
# 648m
# Atomstroieksport
# 0-
# 66m
# 98m
# euros-worth
# Corcostegui
# Rubinsohn
# 'lose
# 'set
# 'hits
# 'more
# 'stronger
# Turkey-Iran
# 'at
# 'slowing
# 'left
# 'Strong
# 'cuts
# 'intact
# ex-aide
# Ex-Boeing
# 'seals
# 'hit
# 'make
# 'loses
# 'not
# 'Post-Christmas
# 'risks
# 'illegal
# 'Standoff
# 'toughest
# 'delayed
# 'genius
# 'fail
# long-living
# 'targeting
# 'ticking
# 'aware
# 'great
# Split-caps
# post-takeover
# 'defies
# 'too
# 'excellent
# 'major
# 'should
# 'poised
# 'controlled
# 'tough
# 'less
# feud-hit
# 100m-share
# 'idle
# 'woo
# 'bids
# 'sets
# EU-US
# 'in
# 'Golden
# 'state
# 'declines
# colludes
# ВЈ600m
# 639m
# search-engine
# 284m
# 09bn
# 2871
# 2974
# ВЈ479m
# 540m
# 141m
# ВЈ125m
# ВЈ106m
# ВЈ59m
# ВЈ250m
# patchier
# 387,500
# 86m
# ВЈ46m
# 204m
# 187m
# 58bn
# badly-needed
# 540bn
# 77bn
# newly-appointed
# 472bn
# ВЈ150m
# ВЈ173
# ELAA
# 'bumping
# EU-based
# pay-out
# Quillinan-Meiland
# tooling-up
# overbalancing
# 77m
# ВЈ53m
# 4bn-euro
# 'BB+
# 'BBB-
# 'always
# 'on
# Sunovate
# ВЈ300m
# ВЈ392
# one-euro
# Kronawitter
# ВЈ484bn
# 162bn
# ВЈ56
# previously-unknown
# 155,465
# Silverade
# 19,924
# 17,815
# Raniers
# non-Opec
# latifundios
# not-too-distant
# 6661
# 'miracle
# 29bn
# UFJ-MTFG
# technology-sharing
# ВЈ546m
# ВЈ532m
# share-ownership
# ВЈ960m
# 85bn
# 364m
# ВЈ30
# soon-to-retire
# ВЈ51
# al-Gosaibi
# highly-educated
# 4850
# -which
# -may
# Ryanair/Boeing
# 34bn
# rapidly-rising
# ВЈ280m
# Wernle
# ВЈ10,000
# ВЈ11,500
# ВЈ17,730
# ВЈ15,690
# ВЈ8,000
# ВЈ12,556
# the-car
# C180
# 116i
# Mini-workers
# ВЈ39
# 861m
# ВЈ451m
# Brabeck-Letmathe
# 53bn
# -best
# 775m
# wholly-
# brain-drain
# small-
# 24bn
# ВЈ130m
# ВЈ234m
# ВЈ220m
# ВЈ610m
# ВЈ105m
# ВЈ80m
# Mong-koo
# ВЈ910m
# 418bn-rand
# BMW-brand
# 80,600
# Rolls-Royces
# ВЈ265m
# ex-head
# Ebber
# 813,200
# ВЈ458m
# 874m
# writeback
# medium-distance
# Schulte-Strathaus
# Weidensteiner
# least-developed
# 300bn
# ВЈ158
# Vancheshwar
# 'automatic
# Chittabrata
# twin-aisle
# rolled-out
# 186m
# ВЈ98m
# 143m
# public-company
# itselfBeer
# beer-like
# Shinnama
# non-beer
# 291m
# ВЈ154m
# third-type
# month-on-month
# Atinc
# Turkish-Austrian
# investment-friendly
# Oganesyan
# 06bn
# capital-raising
# Juchemich
# 635,173
# 546m
# ВЈ290m
# 246,570
# near-400,000
# home-shopping
# food-for-oil
# 'Television
# DHL-owner
# 873p
# Bracknell-based
# ВЈ328m
# 950p
# 82bn
# Komileva
# 901m
# higher-return
# 0619
# 'New
# 119bn
# 113bn
# outweight
# Dogusoy
# part-Turkish
# 51bn
# smaller-than-expected
# January-to-March
# ВЈ486,000
# 705m
# 966m
# ВЈ13
# 2944
# 3006
# four-nation
# 166bn
# seventy-year
# gas-guzzling
# petrol-price
# well-flagged
# anti-bribery
# bigger-than-expected
# 676m
# ВЈ352m
# ВЈ195
# price-rigging
# 618m
# 232m
# 337m
# 360m
# upper-teens
# ВЈ149bn
# ВЈ80,000
# 61m
# ВЈ274
# 73m
# 380m
# dual-ownership
# Sweere
# ВЈ12
# 578m
# 72bn
# PagesJaunes
# '771
# 1,000bn
# ВЈ537bn
# Cross-selling
# NikkoCitigroup
# 785m
# 784m
# 374m
# mini-car
# 506m
# 142bn
# 475m
# DaimerChrysler
# ВЈ722m
# Carl-Henric
# all-communicating
# widely-expected
# 154m
# ВЈ591,000
# 2bn-worth
# tech-production
# 10,385
# ВЈ277m
# ex-senior
# market-timing
# BACAP
# Tambone
# ex-managers
# 50-100,000
# Metrovias
# fast-rising
# ВЈ550m
# 246bn
# ВЈ347m
# ВЈ801m
# ВЈ191m
# 431m
# 245m
# ITPC
# road-show
# ВЈ18
# Rosneft-owned
# London-listed
# Gazprom-Rosneft
# 719m
# re-merchandising
# rock-bottom
# Bridgewell
# stubbornly-high
# Hartz-IV
# Democrat-Green
# internationally-accepted
# ILO-based
# Arcleor
# much-higher
# Sheffield-based
# car-style
# van-style
# mini-van
# Accura
# 3218
# 9094
# 850bn
# ВЈ933m
# 78bn
# Shihab-Eldin
# ВЈ980m
# faming
# fully-operational
# Carl-Peter
# desperately-needed
# ВЈ104m
# 151m
# Vauxhalls
# Tysabri-treated
# re-initiation
# ВЈ152,879
# 1998/9
# vote-catching
# 11,740
# UK-Dutch
# Qatargas-2
# Qatargas-4
# 830bn
# 56bn
# industryIn
# ВЈ131,961
# stategist
# ВЈ11bn
# quarter-point
# cross-London
# ВЈ180,126
# ВЈ178,906
# ВЈ83
# 88bn
# ВЈ0
# 537m
# 701m
# ВЈ371m
# 798m
# 26bn
# 456m
# medium-to-long
# hydroelectric-power
# 365m
# re-selling
# ВЈ280
# 532m
# ВЈ450
# 3187
# Mohi-Uddin
# rock-steady
# 'loan-for-oil
# non-wage
# Beck-Crespel
# Boscholt
# Stueker
# DrKW
# -and
# 1,050-1,125
# 24-
# ex-travel
# 443m
# ВЈ230
# Claquin
# ВЈ581m
# Vioxx-related
# Mihkail
# Westfallen
# 89m
# ВЈ47m
# Peter-Thilo
# Halser
# ВЈ17
# ВЈ2bn
# ВЈ4bn
# record-busting
# Perchesk
# 1130p
# 'tax
# -thought
# -are
# Barrioneuvo
# Kuhlhoff
# belt-tightening
# 230bn
# 587m
# re-orders
# Matshushita
# intellect-enhancing
# 'le
# 684bn
# Moscow-backed
# Veron-Reville
# 'pragmatic
# interest-payment
# Molsiris
# ВЈ266m
# UK-listed
# 548p
# Russian-owned
# Russian-registered
# 339m
# ВЈ182
# ВЈ308m
# 797p
# ВЈ40m-ВЈ50m
# big-ticket
# pay-day
# jelly-legged
# ВЈ135m
# SLBA
# ВЈ49m
# Paion
# Tsusaka
# lower-skilled
# 'card-not-present
# card-present
# UK-issued
# ВЈ402
# Card-not-present
# ВЈ116
# ВЈ43m
# ВЈ52
# PIBS
# ВЈ370m
# ВЈ163,748
# 38bn
# 50bn
# 69bn
# water-and-weather-tight
# well-insulated
# uplights
# downlights
# dimmable
# router/access
# ВЈ35
# ВЈ32
# Interest-sensitive
# ill-serve
# detail-oriented
# July-to-September
# ВЈ182,920
# ВЈ187,971
# July-September
# 36,185
# 28,041
# million-pound
# pro-growth
# 327m
# ВЈ22m
# 31bn
# mis-steps
# direct-sales
# highly-regulated
# Panayis
# Freedom2surf
# IPStream
# 95bn
# 57bn
# dizzyingly-high
# one-lira
# Serdengecti
# slimmed-down
# Hayriye
# ВЈ227bn
# Confifi
# Delaware*
# unguessable
# trillion-dollar
# Reisurance
# Goetti
# Mediterranne
# Floiran
# Woest
# 10,847
# analsyts
# report*
# clearly-defined
# ВЈ250
# ВЈ500
# instant-access
# FirstSaver
# ВЈ4,745
# R85
# non-taxpayer
# ВЈ514m
# red-tape
# ВЈ690m
# early-winter
# Ofex
# money-earning
# 24,997
# Paschoal
# 500bn
# 800bn
# closely-watched
# 572,900
# Jasperneite
# million-2
# energy-starved
# 21bn
# over-egged
# Rhiel
# ВЈ50
# ВЈ46,998
# ВЈ12,700
# 11,488
# Aberdeen-based
# Baghdad-based
# geo-scientists
# 101-year-old
# Torao
# re-devise
# 86bn
# Roukis
# 'Ray
# 5,196
# debt-laden
# 10,137
# tax-cutting
# 422bn
# 10,227
# non-manufacturers
# Multi-Fibre
# 'race
# 790m
# Geijsen
# questionsmarks
# Yuganskneftgas
# Gadaravice
# ВЈ309m
# 725m
# plane-making
# 133m
# N-C
# production-sharing
# 247p
# ВЈ686m
# Anglo-Swedish
# anti-coagulant
# AztraZeneca
# ВЈ135
# 42bn
# made-made
# 105bn
# ВЈ54bn
# scandal-hit
# 97p
# 44p
# ВЈ258
# Everasia
# IOG
# Suba-Luhais
# state-backed
# Kiknavelidze
# 66bn
# 106m
# ВЈ54
# non-convertible
# pence-a-share
# 583p
# 533p
# al-Jibouri
# 260m
# ВЈ134m
# ВЈ4m
# ВЈ25bn
# 98bn
# ВЈ6,500
# 261bn
# fourth-biggest
# Yuganksneftegas
# cannabis-based
# Satifex
# non-defence
# ВЈ211
# Scathes
# AARA
# Reveta
# ВЈ30,800
# state-ownership
# cloak-and-dagger
# Sovlink
# renationalising
# 325m
# Schnaible
# agreed-to
# super-economical
# 200-
# ВЈ55,000
# ВЈ568m
# Junhuai
# 417m
# ВЈ931m
# quick-growing
# ВЈ146m
# 281m
# ВЈ230m
# 47m
# 177,600
# ВЈ140bn
# 258bn
# 560m
# ВЈ291m
# 3516
# 3509
# euro/dollar
# 510m
# ВЈ70m
# tsunami-related
# ВЈ281m
# 640m
# Bermuda-based
# April-July
# ВЈ97m
# April-September
# airlines-
# flight-crew
# court-imposed
# congressionally-mandated
# ex-parent
# Ji-chang
# Yungmin
# Nanik
# Rupani
# Bombay-based
# faster-than-expected
# ВЈ425,000
# Foundation-Kazakhstan
# Abish-uly
# Khordokovsky
# ВЈ269bn
# ВЈ268bn
# US-registered
# 912km
# ВЈ173m
# condom-maker
# Syndol
# Meltus
# value-creating
# ВЈ20
# ВЈ42
# ВЈ23bn
# ВЈ12m
# ВЈ183
# Staropramen
# Leuven-based
# Novocheboksarsk
# ski-maker
# 3652
# 3667
# 960m
# ВЈ499m
# 480m
# Laah
# Chong-gyu
# 3666
# 3636
# co-sign
# Naftohaz
# -owned
# Chada
# 8832
# ВЈ5m
# ВЈ425m
# 779m-798m
# Like-for-like
# ВЈ420m
# FT-30
# ВЈ2m
# Ivankoe
# onstart
# 206,900
# non-seasonally
# communist-style
# pro-Chavez
# Mohieldin
# 74m
# Mitroshin
# pence-per-share
# Ainum
# Navarednam
# Metrojaya
# ВЈ118m
# 376m
# 200p
# ВЈ530m
# 94m
# SimpliFares
# ВЈ264
# Saturday-night
# 646m
# ВЈ24bn
# SalterBaxter
# Lee-Harwood
# pro-sustainability
# ВЈ691m
# 320m
# ВЈ27m
# ВЈ799,000
# genetically-modified
# chemicals-and-crops
# Jakarta-based
# Areen
# ВЈ162,086
# 220bn
# larger-than-forecast
# Neilsen/Net
# 49m
# 449,603
# 44bn
# 925p
# Asia-wide
# 20-30bn
# ВЈ93
# ВЈ89m
# 155m
# ВЈ378
# 2001alleging
# 145m
# ВЈ180,226
# ВЈ180,444
# ВЈ192,713
# ВЈ139,544
# ВЈ116,542
# ВЈ111,314
# ВЈ262,825
# ВЈ96bn
# haute-couture
# Privately-held
# ВЈ522,000
# over-stated
# 40bn
# ВЈ21bn
# Jufeyr
# Sydney-
# freight-carrying
# triple-decker
# 434m
# ВЈ231m
# 732m
# Iliaronov
# 311bn
# ВЈ165bn
# 420bn
# Congressionally-mandated
# 124bn
# 150bn
# 6709
# anti-Musharraf
# shownThe
# ВЈ29bn
# clean-burning
# normal-engined
# Trouble-hit
# evalution
# 717m
# ВЈ379m
# Thadao
# Reline
# Oatleys
# 846m
# Lensworth
# back-flip
# cigarette-making
# Wangli
# STMC
# 210bn
# Schilbe
# ВЈ31
# 3280
# 1,8923
# ВЈ27
# trade-in-services
# Mafeca
# calorie-heavy
# re-positioning
# ВЈ428m
# 'urban
# ВЈ265
# non-store
# 17-a-share
# 'opening
# 584m
# straight-talking
# inflation-fighting
# 492m
# willmean
# 'offshore
# Mijatov
# back-taxes
# ВЈ110m
# 142m
# 387m
# ВЈ206m
# 111m
# 56m
# 761m
# ВЈ481
# 345m
# 569m
# 838m
# 193bn
# 495m
# ВЈ275m
# 330m
# ВЈ750m
# pre-tsunami
# Xiluodi
# 'river
# UK-published
# Nigerian-owned
# Sydney-listed
# Jean-Rene
# ВЈ690,000
# publicly-listed
# Israeli-Egyptian
# 104m
# 793m
# 470m
# ВЈ13m
# full-hybrid
# LR3/Discovery
# 6,798,000
# 1,751,000
# 697m
# 153m
# ASK-Raymond
# non-seasonally-adjusted
# Jessops
# low-prevalence
# 253m
# ВЈ175m
# 328m
# ВЈ775
# ВЈ429m
# 138p
# Leicestershire-based
# ready-mixed
# 745bn
# Dhiru
# ritzier
# ВЈ197bn
# 348bn
# 855bn
# 2-
# Iraq-related
# ВЈ179
# Janeir
# previously-pledged
# 'normal
# Italaudit
# 22,953
# 'I
# ВЈ64m
# China-published
# 190bn
# loans-for-favours
# Scandal-hit
# 220m
# ВЈ117m
# late-November
# 789m
# 03bn
# ВЈ548m
# vehicle-carrying
# ВЈ72
# water-concession
# 242m
# Maghnia
# 39bn
# ВЈ29
# 069
# life-extending
# China'seconomic
# anti-Davos
# 22,201bn
# ВЈ114
# 20,479
# stronger-than-expected
# 208m
# ВЈ111m
# Amusategui
# 'recession
# nine-strong
# over-regulation
# exchange-listed
# 12924

# %%
word2glove = {}
for w in word2idx:
    if w in glove_index_dict:
        g = w
    elif w.lower() in glove_index_dict:
        g = w.lower()
    else:
        continue
    word2glove[w] = g

# %%
# Out:
# [('Surprisingly', 13841, 1.0000000000000004),
#  ('Already', 282, 1.0000000000000002),
#  ('Utility', 2102, 1.0),
#  ('Climate', 2991, 1.0),
#  ('ups', 3544, 1.0),
#  ('Possibly', 11469, 1.0),
#  ('unlike', 5597, 1.0),
#  ('Luxury', 1281, 1.0),
#  ('Aside', 2255, 0.9999999999999999),
#  ('Alabama', 13481, 0.8657759975343173),
#  ('word', 3554, 0.8306937519053538),
#  ('deceived', 5480, 0.8306395957966228),
#  ('lacking', 12024, 0.814095190553351),
#  ('relied', 9296, 0.8115417615070906),
#  ('refugees', 10244, 0.8081844463234502),
#  ('clinics', 3138, 0.8081820976160243),
#  ('themes', 7018, 0.8009017180251088),
#  ('tape', 3666, 0.7956476738037275),
#  ('infected', 4078, 0.7917227449395021),
#  ('greeted', 11417, 0.7876637959589721),
#  ('RBS', 12144, 0.7793660780244019),
#  ('rounds', 3573, 0.7765653927928822),
#  ('luring', 6753, 0.7737950209092075),
#  ('helicopter', 1767, 0.7729538823214096),
#  ('Ivory', 4187, 0.760932335688428),
#  ('overstated', 9283, 0.7595312844786982),
#  ('eve', 542, 0.7467230401726754),
#  ('tractor', 5019, 0.7433986376459485),
#  ('Alice', 7009, 0.7429921234315184),
#  ('unspecified', 8952, 0.7415869393595618),
#  ('kill', 5710, 0.7312127619027216),
#  ('governors', 6257, 0.7105724629711206),
#  ('directing', 5086, 0.6950465769152641),
#  ('classify', 12607, 0.6874888225161153),
#  ('quarrying', 13766, 0.6853810647606338),
#  ('instrumental', 4815, 0.6851126492055118),
#  ('raided', 3052, 0.6768050226231938),
#  ('goodwill', 6802, 0.6703747931584618),
#  ('wild', 9600, 0.6669109465281434),
#  ('Gerrard', 3690, 0.6623035744619721),
#  ('hedged', 5844, 0.6553862479931234),
#  ('orchestrate', 13228, 0.6490533335252641),
#  ('BSE', 7790, 0.6473689061127892),
#  ('Banco', 5637, 0.6441578686598302),
#  ('Maria', 3654, 0.6384643842261687),
#  ('Emilio', 10119, 0.6376031319867747),
#  ('outturn', 5209, 0.6263316767596275),
#  ('curve', 8221, 0.6196191241536945),
#  ('frontman', 5336, 0.6112188487786416),
#  ('Mahindra', 5890, 0.608677804756683),
#  ('Angel', 2768, 0.6043123384138229),
#  ('Abbey', 6879, 0.5944861695389313),
#  ('spurs', 11528, 0.5911047378041302),
#  ('downs', 3990, 0.5854152415238422),
#  ('Hacking', 10002, 0.5712430961214086),
#  ('Angelina', 8573, 0.5466393205371618),
#  ('reconvened', 6439, 0.5146887614648583),
#  ('Sarbanes', 3076, 0.5137675101238015),
#  ('Bono', 5585, 0.5039911659054174),
#  ('vouch', 12608, 0.49248830584244246),
#  ('Jolie', 8573, 0.48741166109632256),
#  ('Oxley', 6279, 0.4824805986798735),
#  ('converge', 11418, 0.47959079800214477),
#  ('Showbiz', 9251, 0.4748987321928857),
#  ('Boateng', 5277, 0.45698669353631266),
#  ('IFRS', 1544, 0.4405309099785319)]

# %%
# Out:
# {'the': 'the',
#  ',': ',',
#  'to': 'to',
#  'of': 'of',
#  'in': 'in',
#  'a': 'a',
#  'and': 'and',
#  "'s": "'s",
#  '``': '``',
#  'The': 'the',
#  'said': 'said',
#  'is': 'is',
#  'for': 'for',
#  'that': 'that',
#  'on': 'on',
#  '%': '%',
#  'has': 'has',
#  "''": "''",
#  'it': 'it',
#  'by': 'by',
#  'its': 'its',
#  'was': 'was',
#  'with': 'with',
#  'as': 'as',
#  'at': 'at',
#  '$': '$',
#  'be': 'be',
#  'from': 'from',
#  'have': 'have',
#  'are': 'are',
#  'US': 'us',
#  'will': 'will',
#  '-': '-',
#  'year': 'year',
#  'Mr': 'mr',
#  'which': 'which',
#  'an': 'an',
#  '(': '(',
#  ')': ')',
#  'had': 'had',
#  'not': 'not',
#  'would': 'would',
#  'been': 'been',
#  'than': 'than',
#  'more': 'more',
#  'also': 'also',
#  'up': 'up',
#  'were': 'were',
#  'market': 'market',
#  'company': 'company',
#  'this': 'this',
#  'their': 'their',
#  'growth': 'growth',
#  'firm': 'firm',
#  'economy': 'economy',
#  'about': 'about',
#  'he': 'he',
#  '1': '1',
#  'but': 'but',
#  'government': 'government',
#  'It': 'it',
#  'new': 'new',
#  'last': 'last',
#  'could': 'could',
#  '2004': '2004',
#  'after': 'after',
#  'sales': 'sales',
#  'economic': 'economic',
#  'over': 'over',
#  'In': 'in',
#  'oil': 'oil',
#  'But': 'but',
#  'they': 'they',
#  'years': 'years',
#  '2': '2',
#  'prices': 'prices',
#  "'": "'",
#  'chief': 'chief',
#  'China': 'china',
#  'two': 'two',
#  'may': 'may',
#  'now': 'now',
#  'one': 'one',
#  'UK': 'uk',
#  'we': 'we',
#  'deal': 'deal',
#  'shares': 'shares',
#  'rise': 'rise',
#  'business': 'business',
#  'out': 'out',
#  '5': '5',
#  'Bank': 'bank',
#  'companies': 'companies',
#  'expected': 'expected',
#  '3': '3',
#  'Yukos': 'yukos',
#  'A': 'a',
#  'world': 'world',
#  'or': 'or',
#  'who': 'who',
#  'However': 'however',
#  'into': 'into',
#  '2005': '2005',
#  '4': '4',
#  'firms': 'firms',
#  'his': 'his',
#  'some': 'some',
#  'dollar': 'dollar',
#  'December': 'december',
#  'country': 'country',
#  'while': 'while',
#  'months': 'months',
#  'against': 'against',
#  'other': 'other',
#  'since': 'since',
#  'people': 'people',
#  'if': 'if',
#  'still': 'still',
#  'rate': 'rate',
#  'European': 'european',
#  'time': 'time',
#  'told': 'told',
#  'there': 'there',
#  '2003': '2003',
#  'first': 'first',
#  'India': 'india',
#  'We': 'we',
#  'financial': 'financial',
#  'demand': 'demand',
#  'all': 'all',
#  'quarter': 'quarter',
#  'down': 'down',
#  'made': 'made',
#  'between': 'between',
#  'countries': 'countries',
#  'rates': 'rates',
#  'interest': 'interest',
#  'such': 'such',
#  'figures': 'figures',
#  'investment': 'investment',
#  'executive': 'executive',
#  'three': 'three',
#  'biggest': 'biggest',
#  'month': 'month',
#  'any': 'any',
#  'spending': 'spending',
#  'profits': 'profits',
#  'price': 'price',
#  'many': 'many',
#  'Europe': 'europe',
#  'state': 'state',
#  'when': 'when',
#  'added': 'added',
#  'bank': 'bank',
#  'group': 'group',
#  '0': '0',
#  'jobs': 'jobs',
#  '8': '8',
#  'tax': 'tax',
#  'offer': 'offer',
#  'back': 'back',
#  '6': '6',
#  'euros': 'euros',
#  'strong': 'strong',
#  'rose': 'rose',
#  'bid': 'bid',
#  'much': 'much',
#  'can': 'can',
#  'trade': 'trade',
#  'costs': 'costs',
#  'set': 'set',
#  'money': 'money',
#  'stock': 'stock',
#  'no': 'no',
#  'analysts': 'analysts',
#  'I': 'i',
#  ';': ';',
#  'only': 'only',
#  'most': 'most',
#  'January': 'january',
#  'foreign': 'foreign',
#  'increase': 'increase',
#  'next': 'next',
#  'should': 'should',
#  'part': 'part',
#  'cut': 'cut',
#  '&': '&',
#  'fall': 'fall',
#  'share': 'share',
#  'budget': 'budget',
#  'million': 'million',
#  'hit': 'hit',
#  'make': 'make',
#  '10': '10',
#  'week': 'week',
#  'our': 'our',
#  'London': 'london',
#  'recent': 'recent',
#  'He': 'he',
#  'high': 'high',
#  'Russian': 'russian',
#  'well': 'well',
#  'Japan': 'japan',
#  'do': 'do',
#  'move': 'move',
#  'take': 'take',
#  'Deutsche': 'deutsche',
#  'under': 'under',
#  'industry': 'industry',
#  'says': 'says',
#  'during': 'during',
#  'being': 'being',
#  'debt': 'debt',
#  'United': 'united',
#  'likely': 'likely',
#  'pay': 'pay',
#  'report': 'report',
#  'production': 'production',
#  '7': '7',
#  'fell': 'fell',
#  'This': 'this',
#  'higher': 'higher',
#  'reported': 'reported',
#  'deficit': 'deficit',
#  'former': 'former',
#  'annual': 'annual',
#  'say': 'say',
#  'Russia': 'russia',
#  'investors': 'investors',
#  'sale': 'sale',
#  'President': 'president',
#  'because': 'because',
#  'news': 'news',
#  'court': 'court',
#  'EU': 'eu',
#  'bankruptcy': 'bankruptcy',
#  'just': 'just',
#  'number': 'number',
#  'continue': 'continue',
#  'further': 'further',
#  'off': 'off',
#  'cost': 'cost',
#  'plans': 'plans',
#  'New': 'new',
#  '9': '9',
#  'record': 'record',
#  'main': 'main',
#  'November': 'november',
#  'exports': 'exports',
#  'public': 'public',
#  'seen': 'seen',
#  'case': 'case',
#  'end': 'end',
#  'giant': 'giant',
#  'future': 'future',
#  'South': 'south',
#  'profit': 'profit',
#  'unit': 'unit',
#  'markets': 'markets',
#  'less': 'less',
#  'both': 'both',
#  'Analysts': 'analysts',
#  'largest': 'largest',
#  'boost': 'boost',
#  ':': ':',
#  'too': 'too',
#  'trading': 'trading',
#  'statement': 'statement',
#  'fraud': 'fraud',
#  'euro': 'euro',
#  'consumer': 'consumer',
#  'need': 'need',
#  'sector': 'sector',
#  'car': 'car',
#  'lost': 'lost',
#  'agreed': 'agreed',
#  'German': 'german',
#  'work': 'work',
#  'meeting': 'meeting',
#  'already': 'already',
#  'GM': 'gm',
#  'before': 'before',
#  'so': 'so',
#  'put': 'put',
#  'according': 'according',
#  'shareholders': 'shareholders',
#  "n't": "n't",
#  'LSE': 'lse',
#  'stake': 'stake',
#  'low': 'low',
#  'takeover': 'takeover',
#  'buy': 'buy',
#  'global': 'global',
#  'value': 'value',
#  'decision': 'decision',
#  'earlier': 'earlier',
#  'warned': 'warned',
#  'including': 'including',
#  'came': 'came',
#  'saying': 'saying',
#  'see': 'see',
#  'club': 'club',
#  'previous': 'previous',
#  'domestic': 'domestic',
#  'help': 'help',
#  'current': 'current',
#  'through': 'through',
#  'banks': 'banks',
#  'Tuesday': 'tuesday',
#  'Gazprom': 'gazprom',
#  'past': 'past',
#  'airline': 'airline',
#  'October': 'october',
#  'analyst': 'analyst',
#  'them': 'them',
#  'latest': 'latest',
#  'did': 'did',
#  'get': 'get',
#  'Fiat': 'fiat',
#  'total': 'total',
#  'talks': 'talks',
#  'good': 'good',
#  'very': 'very',
#  'announced': 'announced',
#  '30': '30',
#  'board': 'board',
#  'second': 'second',
#  'earnings': 'earnings',
#  'way': 'way',
#  'economist': 'economist',
#  'key': 'key',
#  'five': 'five',
#  'There': 'there',
#  'Bush': 'bush',
#  'period': 'period',
#  'major': 'major',
#  'sold': 'sold',
#  'products': 'products',
#  'Boerse': 'boerse',
#  'Indian': 'indian',
#  'own': 'own',
#  'president': 'president',
#  'top': 'top',
#  '20': '20',
#  'Friday': 'friday',
#  'Commission': 'commission',
#  'fuel': 'fuel',
#  'level': 'level',
#  'data': 'data',
#  'Glazer': 'glazer',
#  'Thursday': 'thursday',
#  'Group': 'group',
#  'where': 'where',
#  'output': 'output',
#  'ahead': 'ahead',
#  'lower': 'lower',
#  'however': 'however',
#  'September': 'september',
#  'half': 'half',
#  'recovery': 'recovery',
#  'Ebbers': 'ebbers',
#  'reports': 'reports',
#  'exchange': 'exchange',
#  'They': 'they',
#  'agreement': 'agreement',
#  'those': 'those',
#  'what': 'what',
#  'operations': 'operations',
#  'Asia': 'asia',
#  'assets': 'assets',
#  'York': 'york',
#  'bought': 'bought',
#  'following': 'following',
#  'Exchange': 'exchange',
#  'On': 'on',
#  'remain': 'remain',
#  'due': 'due',
#  'going': 'going',
#  '12': '12',
#  'index': 'index',
#  'impact': 'impact',
#  'charges': 'charges',
#  'director': 'director',
#  'close': 'close',
#  'Germany': 'germany',
#  'go': 'go',
#  'despite': 'despite',
#  'far': 'far',
#  'how': 'how',
#  'even': 'even',
#  '15': '15',
#  'France': 'france',
#  'increased': 'increased',
#  'gas': 'gas',
#  'inflation': 'inflation',
#  'plan': 'plan',
#  'Reuters': 'reuters',
#  'forecast': 'forecast',
#  'Shares': 'shares',
#  'finance': 'finance',
#  'Yugansk': 'yugansk',
#  'come': 'come',
#  'support': 'support',
#  'early': 'early',
#  'face': 'face',
#  'Japanese': 'japanese',
#  'cash': 'cash',
#  'development': 'development',
#  '1bn': '1bn',
#  'control': 'control',
#  'World': 'world',
#  'legal': 'legal',
#  'result': 'result',
#  'Rosneft': 'rosneft',
#  'law': 'law',
#  'these': 'these',
#  'same': 'same',
#  'currently': 'currently',
#  'businesses': 'businesses',
#  'spokesman': 'spokesman',
#  'action': 'action',
#  'IMF': 'imf',
#  'four': 'four',
#  'manufacturing': 'manufacturing',
#  'currency': 'currency',
#  '3bn': '3bn',
#  'workers': 'workers',
#  'believe': 'believe',
#  'Monday': 'monday',
#  'Wednesday': 'wednesday',
#  'corporate': 'corporate',
#  'rising': 'rising',
#  'America': 'america',
#  'accounts': 'accounts',
#  'big': 'big',
#  'private': 'private',
#  'does': 'does',
#  'job': 'job',
#  'house': 'house',
#  '11': '11',
#  'chairman': 'chairman',
#  'making': 'making',
#  'below': 'below',
#  'As': 'as',
#  'whether': 'whether',
#  'until': 'until',
#  'insurance': 'insurance',
#  'credit': 'credit',
#  'cuts': 'cuts',
#  'third': 'third',
#  'unemployment': 'unemployment',
#  'leading': 'leading',
#  'found': 'found',
#  '2002': '2002',
#  'retail': 'retail',
#  'few': 'few',
#  'MCI': 'mci',
#  'remains': 'remains',
#  'around': 'around',
#  'customers': 'customers',
#  'almost': 'almost',
#  'And': 'and',
#  '2001': '2001',
#  'minister': 'minister',
#  'long': 'long',
#  'Chinese': 'chinese',
#  'BBC': 'bbc',
#  'then': 'then',
#  'day': 'day',
#  'average': 'average',
#  'policy': 'policy',
#  'property': 'property',
#  'order': 'order',
#  'revenues': 'revenues',
#  'account': 'account',
#  'agency': 'agency',
#  'At': 'at',
#  'use': 'use',
#  'levels': 'levels',
#  'executives': 'executives',
#  'rules': 'rules',
#  'aid': 'aid',
#  'SEC': 'sec',
#  'better': 'better',
#  'energy': 'energy',
#  'auction': 'auction',
#  '25': '25',
#  'growing': 'growing',
#  'results': 'results',
#  'saw': 'saw',
#  'think': 'think',
#  'start': 'start',
#  'possible': 'possible',
#  'ago': 'ago',
#  'meet': 'meet',
#  'rival': 'rival',
#  'staff': 'staff',
#  'forced': 'forced',
#  'performance': 'performance',
#  'If': 'if',
#  'protection': 'protection',
#  'political': 'political',
#  'According': 'according',
#  'large': 'large',
#  'best': 'best',
#  'although': 'although',
#  'survey': 'survey',
#  'problems': 'problems',
#  'Boeing': 'boeing',
#  'housing': 'housing',
#  'Securities': 'securities',
#  'taking': 'taking',
#  'international': 'international',
#  'compared': 'compared',
#  'Financial': 'financial',
#  'Last': 'last',
#  'like': 'like',
#  'led': 'led',
#  'give': 'give',
#  'Iraq': 'iraq',
#  'competition': 'competition',
#  'Minister': 'minister',
#  'services': 'services',
#  'taken': 'taken',
#  'officials': 'officials',
#  'took': 'took',
#  'product': 'product',
#  'least': 'least',
#  '2006': '2006',
#  'look': 'look',
#  'across': 'across',
#  'French': 'french',
#  'change': 'change',
#  '2bn': '2bn',
#  'News': 'news',
#  'Christmas': 'christmas',
#  'fourth': 'fourth',
#  'among': 'among',
#  'International': 'international',
#  'Ms': 'ms',
#  'authorities': 'authorities',
#  'another': 'another',
#  'claims': 'claims',
#  'Its': 'its',
#  'target': 'target',
#  'given': 'given',
#  'become': 'become',
#  'used': 'used',
#  'figure': 'figure',
#  'claim': 'claim',
#  'banking': 'banking',
#  'above': 'above',
#  'WorldCom': 'worldcom',
#  'hold': 'hold',
#  '50': '50',
#  'trillion': 'trillion',
#  'needed': 'needed',
#  'February': 'february',
#  'enough': 'enough',
#  'showed': 'showed',
#  'England': 'england',
#  'crude': 'crude',
#  'confidence': 'confidence',
#  'Sri': 'sri',
#  'Stock': 'stock',
#  'maker': 'maker',
#  'helped': 'helped',
#  'keep': 'keep',
#  'yet': 'yet',
#  'having': 'having',
#  'nations': 'nations',
#  'raise': 'raise',
#  'Union': 'union',
#  'later': 'later',
#  'recently': 'recently',
#  'senior': 'senior',
#  'general': 'general',
#  'accounting': 'accounting',
#  'mortgage': 'mortgage',
#  'Air': 'air',
#  'sell': 'sell',
#  'fund': 'fund',
#  'decline': 'decline',
#  'GDP': 'gdp',
#  'previously': 'previously',
#  'include': 'include',
#  'creditors': 'creditors',
#  'British': 'british',
#  'March': 'march',
#  'rather': 'rather',
#  'days': 'days',
#  'create': 'create',
#  'significant': 'significant',
#  'loss': 'loss',
#  'consumers': 'consumers',
#  'risk': 'risk',
#  'accused': 'accused',
#  'Khodorkovsky': 'khodorkovsky',
#  'Standard': 'standard',
#  'slowdown': 'slowdown',
#  'Turkey': 'turkey',
#  'run': 'run',
#  'losses': 'losses',
#  'point': 'point',
#  'closed': 'closed',
#  'That': 'that',
#  'called': 'called',
#  'pressure': 'pressure',
#  'taxes': 'taxes',
#  'American': 'american',
#  'term': 'term',
#  'concerns': 'concerns',
#  'head': 'head',
#  'hopes': 'hopes',
#  'held': 'held',
#  'looking': 'looking',
#  'focus': 'focus',
#  'Some': 'some',
#  'comes': 'comes',
#  'worth': 'worth',
#  'areas': 'areas',
#  'trying': 'trying',
#  'affected': 'affected',
#  'telecoms': 'telecoms',
#  'cars': 'cars',
#  'poor': 'poor',
#  'show': 'show',
#  'Korea': 'korea',
#  'Euronext': 'euronext',
#  'conditions': 'conditions',
#  'yen': 'yen',
#  'Sunday': 'sunday',
#  'huge': 'huge',
#  '100': '100',
#  'little': 'little',
#  'mobile': 'mobile',
#  'Marsh': 'marsh',
#  'members': 'members',
#  'Lanka': 'lanka',
#  'you': 'you',
#  'airlines': 'airlines',
#  'For': 'for',
#  'grew': 'grew',
#  'revenue': 'revenue',
#  'administration': 'administration',
#  'means': 'means',
#  'National': 'national',
#  'official': 'official',
#  'want': 'want',
#  'within': 'within',
#  'home': 'home',
#  'Street': 'street',
#  'six': 'six',
#  'net': 'net',
#  'management': 'management',
#  'paid': 'paid',
#  'national': 'national',
#  'Despite': 'despite',
#  '16': '16',
#  'income': 'income',
#  'BMW': 'bmw',
#  'grow': 'grow',
#  'evidence': 'evidence',
#  'Africa': 'africa',
#  'facing': 'facing',
#  'amount': 'amount',
#  'reached': 'reached',
#  'goods': 'goods',
#  'Department': 'department',
#  'signed': 'signed',
#  'coming': 'coming',
#  'benefits': 'benefits',
#  '18': '18',
#  'working': 'working',
#  'selling': 'selling',
#  'overall': 'overall',
#  'dropped': 'dropped',
#  'proposals': 'proposals',
#  'slow': 'slow',
#  'lending': 'lending',
#  'power': 'power',
#  'trial': 'trial',
#  'once': 'once',
#  'Indonesia': 'indonesia',
#  '2000': '2000',
#  'expectations': 'expectations',
#  'highest': 'highest',
#  'Federal': 'federal',
#  'late': 'late',
#  'fallen': 'fallen',
#  'per': 'per',
#  'must': 'must',
#  'falling': 'falling',
#  'officer': 'officer',
#  'line': 'line',
#  'potential': 'potential',
#  'loans': 'loans',
#  'Sullivan': 'sullivan',
#  'central': 'central',
#  'May': 'may',
#  'election': 'election',
#  'turn': 'turn',
#  'funds': 'funds',
#  'forecasts': 'forecasts',
#  'leaders': 'leaders',
#  'expects': 'expects',
#  'dollars': 'dollars',
#  'each': 'each',
#  'adding': 'adding',
#  'activity': 'activity',
#  'she': 'she',
#  'Italian': 'italian',
#  'continued': 'continued',
#  'economists': 'economists',
#  'While': 'while',
#  'return': 'return',
#  'S': 's',
#  'Australia': 'australia',
#  'shareholder': 'shareholder',
#  'compensation': 'compensation',
#  'full': 'full',
#  'drop': 'drop',
#  'damage': 'damage',
#  'supply': 'supply',
#  'buying': 'buying',
#  'slightly': 'slightly',
#  'newspaper': 'newspaper',
#  'thought': 'thought',
#  'filed': 'filed',
#  '40': '40',
#  'estimated': 'estimated',
#  '14': '14',
#  'research': 'research',
#  'left': 'left',
#  'announcement': 'announcement',
#  'needs': 'needs',
#  'right': 'right',
#  'local': 'local',
#  'itself': 'itself',
#  'One': 'one',
#  'fact': 'fact',
#  'health': 'health',
#  'Meanwhile': 'meanwhile',
#  'capital': 'capital',
#  'important': 'important',
#  'rupees': 'rupees',
#  'Fed': 'fed',
#  'boss': 'boss',
#  'weak': 'weak',
#  'settlement': 'settlement',
#  'amid': 'amid',
#  'phone': 'phone',
#  'Asian': 'asian',
#  'drug': 'drug',
#  'find': 'find',
#  'office': 'office',
#  'makes': 'makes',
#  'pace': 'pace',
#  'Trade': 'trade',
#  'industrial': 'industrial',
#  'owns': 'owns',
#  'operating': 'operating',
#  'debts': 'debts',
#  'raised': 'raised',
#  'positive': 'positive',
#  'continuing': 'continuing',
#  'Airbus': 'airbus',
#  'wants': 'wants',
#  'cutting': 'cutting',
#  'April': 'april',
#  '17': '17',
#  'David': 'david',
#  'system': 'system',
#  'weeks': 'weeks',
#  'Under': 'under',
#  'proposal': 'proposal',
#  'problem': 'problem',
#  'Economic': 'economic',
#  'able': 'able',
#  'times': 'times',
#  'investigation': 'investigation',
#  'guilty': 'guilty',
#  'construction': 'construction',
#  'aircraft': 'aircraft',
#  'Argentina': 'argentina',
#  'Oil': 'oil',
#  'service': 'service',
#  'reduce': 'reduce',
#  'risen': 'risen',
#  'speculation': 'speculation',
#  'issue': 'issue',
#  'Brown': 'brown',
#  'place': 'place',
#  'programme': 'programme',
#  'nearly': 'nearly',
#  'allow': 'allow',
#  'points': 'points',
#  'list': 'list',
#  'provide': 'provide',
#  'directors': 'directors',
#  'John': 'john',
#  'fiscal': 'fiscal',
#  'Parmalat': 'parmalat',
#  'access': 'access',
#  'call': 'call',
#  'rule': 'rule',
#  'merger': 'merger',
#  'Ukraine': 'ukraine',
#  'issues': 'issues',
#  'reforms': 'reforms',
#  'projects': 'projects',
#  'similar': 'similar',
#  'short': 'short',
#  'food': 'food',
#  'Times': 'times',
#  'policies': 'policies',
#  'General': 'general',
#  'approval': 'approval',
#  'based': 'based',
#  'known': 'known',
#  'strength': 'strength',
#  'though': 'though',
#  'difficult': 'difficult',
#  'collapse': 'collapse',
#  'Yuganskneftegas': 'yuganskneftegas',
#  'Baikal': 'baikal',
#  'Manchester': 'manchester',
#  'gains': 'gains',
#  'Rover': 'rover',
#  'extra': 'extra',
#  'again': 'again',
#  'built': 'built',
#  'final': 'final',
#  'brands': 'brands',
#  'vehicles': 'vehicles',
#  'expect': 'expect',
#  'lead': 'lead',
#  'changes': 'changes',
#  'whose': 'whose',
#  'expansion': 'expansion',
#  'might': 'might',
#  '28': '28',
#  'driven': 'driven',
#  'majority': 'majority',
#  'asked': 'asked',
#  'building': 'building',
#  'lot': 'lot',
#  'project': 'project',
#  'Australian': 'australian',
#  'contract': 'contract',
#  'process': 'process',
#  'build': 'build',
#  'Barclays': 'barclays',
#  'owner': 'owner',
#  'steel': 'steel',
#  'reserves': 'reserves',
#  'fears': 'fears',
#  'continues': 'continues',
#  'risks': 'risks',
#  'travel': 'travel',
#  'effect': 'effect',
#  'real': 'real',
#  'blamed': 'blamed',
#  'outlook': 'outlook',
#  'Paris': 'paris',
#  'terms': 'terms',
#  'created': 'created',
#  'employment': 'employment',
#  'federal': 'federal',
#  'region': 'region',
#  'disaster': 'disaster',
#  'several': 'several',
#  'investments': 'investments',
#  'With': 'with',
#  'running': 'running',
#  'North': 'north',
#  'whole': 'whole',
#  'August': 'august',
#  'effort': 'effort',
#  'failed': 'failed',
#  'Office': 'office',
#  'area': 'area',
#  'centre': 'centre',
#  'wine': 'wine',
#  'Italy': 'italy',
#  'listing': 'listing',
#  'ministers': 'ministers',
#  'role': 'role',
#  'scandal': 'scandal',
#  'WTO': 'wto',
#  'open': 'open',
#  'G7': 'g7',
#  'payments': 'payments',
#  'reform': 'reform',
#  'card': 'card',
#  'poverty': 'poverty',
#  'family': 'family',
#  'internet': 'internet',
#  'comment': 'comment',
#  'claimed': 'claimed',
#  'showing': 'showing',
#  'small': 'small',
#  'information': 'information',
#  'position': 'position',
#  'producer': 'producer',
#  'launch': 'launch',
#  'him': 'him',
#  'denied': 'denied',
#  'quoted': 'quoted',
#  'stores': 'stores',
#  'Lisbon': 'lisbon',
#  'rights': 'rights',
#  'Saudi': 'saudi',
#  'plant': 'plant',
#  'subsidies': 'subsidies',
#  'factory': 'factory',
#  'Brazil': 'brazil',
#  'planning': 'planning',
#  'rises': 'rises',
#  'retailers': 'retailers',
#  'stronger': 'stronger',
#  'division': 'division',
#  '27': '27',
#  'efforts': 'efforts',
#  'Reserve': 'reserve',
#  'States': 'states',
#  'developing': 'developing',
#  'rejected': 'rejected',
#  'behind': 'behind',
#  'planned': 'planned',
#  'Many': 'many',
#  'Airlines': 'airlines',
#  'force': 'force',
#  'technology': 'technology',
#  '13': '13',
#  'clear': 'clear',
#  'subsidiary': 'subsidiary',
#  'July': 'july',
#  'Congress': 'congress',
#  'These': 'these',
#  'longer': 'longer',
#  'lawyers': 'lawyers',
#  'without': 'without',
#  'network': 'network',
#  'bill': 'bill',
#  'passengers': 'passengers',
#  'gap': 'gap',
#  'ruling': 'ruling',
#  'Cairn': 'cairn',
#  'Sales': 'sales',
#  'Corp': 'corp',
#  'children': 'children',
#  'Wall': 'wall',
#  'Swiss': 'swiss',
#  'existing': 'existing',
#  'savings': 'savings',
#  'went': 'went',
#  'limited': 'limited',
#  'Motors': 'motors',
#  'using': 'using',
#  'massive': 'massive',
#  'Thailand': 'thailand',
#  'range': 'range',
#  'cards': 'cards',
#  '70': '70',
#  'brand': 'brand',
#  'signs': 'signs',
#  'remained': 'remained',
#  'believed': 'believed',
#  'tough': 'tough',
#  'Although': 'although',
#  'situation': 'situation',
#  'ONS': 'ons',
#  'life': 'life',
#  'recession': 'recession',
#  'tobacco': 'tobacco',
#  'reach': 'reach',
#  'improve': 'improve',
#  'Airways': 'airways',
#  'Nissan': 'nissan',
#  'offered': 'offered',
#  'unlikely': 'unlikely',
#  'predicted': 'predicted',
#  'tsunami': 'tsunami',
#  'spent': 'spent',
#  'us': 'us',
#  'suffered': 'suffered',
#  'Association': 'association',
#  'launched': 'launched',
#  'overseas': 'overseas',
#  'damages': 'damages',
#  'available': 'available',
#  'imports': 'imports',
#  'particularly': 'particularly',
#  'develop': 'develop',
#  'economies': 'economies',
#  'member': 'member',
#  '1990s': '1990s',
#  'received': 'received',
#  'restructuring': 'restructuring',
#  ...}
