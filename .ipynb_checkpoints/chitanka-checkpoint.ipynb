# %%
import asyncio
import aiohttp
async def some_function(i):
    async with aiohttp.ClientSession() as session:
        async with session.get("https://chitanka.info/book/16-hamlet.txt.zip") as resp:
            print(resp.status)
            
loop = asyncio.get_event_loop()
tasks = []
for i in range(1, 2):
    tasks.append(loop.create_task(some_function(i)))
loop.run_until_complete(asyncio.wait(tasks))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c6d34fdf0445> in <module>()
#      10 for i in range(1, 2):
#      11     tasks.append(loop.create_task(some_function(i)))
# ---> 12 loop.run_until_complete(asyncio.wait(tasks))
#
# D:\Programs\Anaconda\lib\asyncio\base_events.py in run_until_complete(self, future)
#     452         future.add_done_callback(_run_until_complete_cb)
#     453         try:
# --> 454             self.run_forever()
#     455         except:
#     456             if new_task and future.done() and not future.cancelled():
#
# D:\Programs\Anaconda\lib\asyncio\base_events.py in run_forever(self)
#     419             events._set_running_loop(self)
#     420             while True:
# --> 421                 self._run_once()
#     422                 if self._stopping:
#     423                     break
#
# D:\Programs\Anaconda\lib\asyncio\base_events.py in _run_once(self)
#    1429                     self._current_handle = None
#    1430             else:
# -> 1431                 handle._run()
#    1432         handle = None  # Needed to break cycles when an exception occurs.
#    1433
#
# D:\Programs\Anaconda\lib\asyncio\events.py in _run(self)
#     143     def _run(self):
#     144         try:
# --> 145             self._callback(*self._args)
#     146         except Exception as exc:
#     147             cb = _format_callback_source(self._callback, self._args)
#
# <ipython-input-2-6aea4b49e273> in some_function(i)
#       5         async with session.get("https://chitanka.info/book/16-hamlet.txt.zip") as resp:
#       6             print(resp.status)
# ----> 7             print(await resp.text())
#       8
#       9 loop = asyncio.get_event_loop()
#
# D:\Programs\Anaconda\lib\site-packages\aiohttp\client_reqrep.py in text(self, encoding, errors)
#     830
#     831         if encoding is None:
# --> 832             encoding = self.get_encoding()
#     833
#     834         return self._content.decode(encoding, errors=errors)
#
# D:\Programs\Anaconda\lib\site-packages\aiohttp\client_reqrep.py in get_encoding(self)
#     818                 encoding = 'utf-8'
#     819             else:
# --> 820                 encoding = chardet.detect(self._content)['encoding']
#     821         if not encoding:
#     822             encoding = 'utf-8'
#
# D:\Programs\Anaconda\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      36             byte_str = bytearray(byte_str)
#      37     detector = UniversalDetector()
# ---> 38     detector.feed(byte_str)
#      39     return detector.close()
#
# D:\Programs\Anaconda\lib\site-packages\chardet\universaldetector.py in feed(self, byte_str)
#     209                 self._charset_probers.append(Latin1Prober())
#     210             for prober in self._charset_probers:
# --> 211                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     212                     self.result = {'encoding': prober.charset_name,
#     213                                    'confidence': prober.get_confidence(),
#
# D:\Programs\Anaconda\lib\site-packages\chardet\charsetgroupprober.py in feed(self, byte_str)
#      69             if not prober.active:
#      70                 continue
# ---> 71             state = prober.feed(byte_str)
#      72             if not state:
#      73                 continue
#
# D:\Programs\Anaconda\lib\site-packages\chardet\sbcharsetprober.py in feed(self, byte_str)
#     103                         model = self._model['precedence_matrix'][i]
#     104                     self._seq_counters[model] += 1
# --> 105             self._last_order = order
#     106
#     107         charset_name = self._model['charset_name']
#
# KeyboardInterrupt:

# %%
try:
    from urllib.request import urlopen
    import urllib
except ImportError:
    from urllib2 import urlopen

try:
    html = urlopen("https://chitanka.info/book/16-hamlet.txt.zip")
    data = html.read().decode("utf-8")
    print (data)
    print ('-----------------------------------------------------------')
except urllib.error.HTTPError:
    pass

# %%
import requests, zipfile, io
r = requests.get('https://chitanka.info/book/16-hamlet.txt.zip')
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("C:/Users/pepy_/Desktop/HackTues30x/chitankaTests")

# %%
#from BeautifulSoup import BeautifulSoup
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

html_page = urlopen("https://chitanka.info/")
html_page.read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-43ac9578b2de> in <module>()
#       4 import re
#       5
# ----> 6 html_page = urlopen("https://chitanka.info/")
#       7 html_page.read()
#       8
#
# D:\Programs\Anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# D:\Programs\Anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# D:\Programs\Anaconda\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# D:\Programs\Anaconda\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# D:\Programs\Anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# D:\Programs\Anaconda\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import urllib.request
from bs4 import BeautifulSoup

user_agent = 'Mozilla/5.0' #(Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7

url = "https://chitanka.info"
headers={'User-Agent':user_agent} 

request=urllib.request.Request(url,None,headers)
response = urllib.request.urlopen(request)
data = response.read().decode("utf-8")
soup = BeautifulSoup(data, 'html.parser')
myattribute = soup.findAll('a', {"class": "btn btn-default dl dl-txt action"})
for a in myattribute:
    print(a)
#print(data)
# Out:
# <a href="#main-content">основното съдържание</a>
# <a href="#navigation">менюто</a>
# <a href="#search">търсачката</a>
# <a href="//chitanka.info">Библиотека</a>
# <a href="//biblioman.chitanka.info">Библиоман</a>
# <a href="//forum.chitanka.info">Форум</a>
# <a href="//prevodi.chitanka.info">Дачко</a>
# <a href="//wiki.workroom.chitanka.info">Читалие</a>
# <a href="//rechnik.chitanka.info">Речник</a>
# <a href="//gramofonche.chitanka.info">Грамофонче</a>
# <a href="//tools.chitanka.info">Сръчко</a>
# <a href="/authors"><span class="fa fa-users"></span><br/>Автори</a>
# <a href="/translators"><span class="fa fa-edit"></span><br/>Преводачи</a>
# <a href="/books"><span class="fa fa-book"></span><br/>Книги</a>
# <a href="/texts"><span class="fa fa-folder-open"></span><br/>Творби</a>
# <a href="/series"><span class="fa fa-sitemap"></span><br/>Серии</a>
# <a href="/new"><span class="fa fa-calendar"></span><br/>Ново</a>
# <a href="/workroom"><span class="fa fa-table"></span><br/>Ателие</a>
# <a href="/new/books">Нови книги</a>
# <a class="booklink" data-edit="/admin/book/8417/edit" href="/book/8417-detsata-ot-ulitsa-trjaskadzhijska">
# <i itemprop="name">Децата от улица „Тряскаджийска“</i>
# </a>
# <a data-edit="/admin/person/33/edit" href="/person/astrid-lindgren" itemprop="name">Астрид Линдгрен</a>
# <a data-edit="/admin/sequence/713/edit" href="/sequence/kolektsija-astrid-lindgren" rel="category">Колекция „Астрид Линдгрен“</a>
# <a data-edit="/admin/category/80/edit" href="/books/category/romani-i-povesti-za-deca" rel="category tag">Романи и повести за деца</a>
# <a class="btn btn-default dl dl-fb2 action" href="/book/8417-detsata-ot-ulitsa-trjaskadzhijska.fb2.zip" title="Сваляне във формат fb2.zip"><span class="sr-only">fb2.zip</span></a>
# <a class="btn btn-default dl dl-epub action" href="/book/8417-detsata-ot-ulitsa-trjaskadzhijska.epub" title="Сваляне във формат epub"><span class="sr-only">epub</span></a>
# <a class="btn btn-default dl dl-txt action" href="/book/8417-detsata-ot-ulitsa-trjaskadzhijska.txt.zip" title="Сваляне във формат txt.zip"><span class="sr-only">txt.zip</span></a>
# <a class="btn btn-default dl dl-sfb action" href="/book/8417-detsata-ot-ulitsa-trjaskadzhijska.sfb.zip" title="Сваляне във формат sfb.zip"><span class="sr-only">sfb.zip</span></a>
# <a class="btn btn-default dl biblioman-link" href="//biblioman.chitanka.info/books/4515" title="Запис за книгата в Библиоман"><span class="sr-only">Библиоман</span></a>
# <a class="booklink" data-edit="/admin/book/8416/edit" href="/book/8416-franklin-tomas">
# <i itemprop="name">Франклин Томас</i>
# </a>
# <a data-edit="/admin/person/9498/edit" href="/person/donko-najdenov" itemprop="name">Донко Найденов</a>
# <a data-edit="/admin/category/78/edit" href="/books/category/savremenni-balgarski-romani-i-povesti" rel="category tag">Съвременни български романи и повести</a>
# <a class="btn btn-default dl dl-fb2 action" href="/book/8416-franklin-tomas.fb2.zip" title="Сваляне във формат fb2.zip"><span class="sr-only">fb2.zip</span></a>
# <a class="btn btn-default dl dl-epub action" href="/book/8416-franklin-tomas.epub" title="Сваляне във формат epub"><span class="sr-only">epub</span></a>
# <a class="btn btn-default dl dl-txt action" href="/book/8416-franklin-tomas.txt.zip" title="Сваляне във формат txt.zip"><span class="sr-only">txt.zip</span></a>
# <a class="btn btn-default dl dl-sfb action" href="/book/8416-franklin-tomas.sfb.zip" title="Сваляне във формат sfb.zip"><span class="sr-only">sfb.zip</span></a>
# <a class="btn btn-default dl biblioman-link" href="//biblioman.chitanka.info/books/3627" title="Запис за книгата в Библиоман"><span class="sr-only">Библиоман</span></a>
# <a class="booklink" data-edit="/admin/book/8415/edit" href="/book/8415-direktivata-jansyn">
# <i itemprop="name">Директивата „Янсън“</i>
# </a>
# <a data-edit="/admin/person/346/edit" href="/person/robert-ludlum" itemprop="name">Робърт Лъдлъм</a>
# <a data-edit="/admin/sequence/718/edit" href="/sequence/kolektsija-robyrt-lydlym" rel="category">Колекция Робърт Лъдлъм</a>
# <a data-edit="/admin/category/28/edit" href="/books/category/thriller" rel="category tag">Трилър</a>
# <a class="btn btn-default dl dl-fb2 action" href="/book/8415-direktivata-jansyn.fb2.zip" title="Сваляне във формат fb2.zip"><span class="sr-only">fb2.zip</span></a>
# <a class="btn btn-default dl dl-epub action" href="/book/8415-direktivata-jansyn.epub" title="Сваляне във формат epub"><span class="sr-only">epub</span></a>
# <a class="btn btn-default dl dl-txt action" href="/book/8415-direktivata-jansyn.txt.zip" title="Сваляне във формат txt.zip"><span class="sr-only">txt.zip</span></a>
# <a class="btn btn-default dl dl-sfb action" href="/book/8415-direktivata-jansyn.sfb.zip" title="Сваляне във формат sfb.zip"><span class="sr-only">sfb.zip</span></a>
# <a class="btn btn-default dl biblioman-link" href="//biblioman.chitanka.info/books/3268" title="Запис за книгата в Библиоман"><span class="sr-only">Библиоман</span></a>
# <a href="/new/books">Още нови книги</a>
# <a href="/new/texts">Нови произведения</a>
# <a class="textlink" data-edit="/admin/text/39307/edit" href="/text/39307-nabljudatelite" itemprop="name" title=""><i>Наблюдателите</i></a>
# <a data-edit="/admin/person/435/edit" href="/person/ray-bradbury" itemprop="name">Рей Бредбъри</a>
# <a class="textlink" data-edit="/admin/text/39306/edit" href="/text/39306-lota-se-mesti-ot-kyshti" itemprop="name" title=""><i>Лота се мести от къщи</i></a>
# <a data-edit="/admin/person/33/edit" href="/person/astrid-lindgren" itemprop="name">Астрид Линдгрен</a>
# <a class="textlink" data-edit="/admin/text/39305/edit" href="/text/39305-detsata-ot-ulitsa-trjaskadzhijska" itemprop="name" title=""><i>Децата от улица „Тряскаджийска“</i></a>
# <a data-edit="/admin/person/33/edit" href="/person/astrid-lindgren" itemprop="name">Астрид Линдгрен</a>
# <a class="textlink" data-edit="/admin/text/39304/edit" href="/text/39304-franklin-tomas" itemprop="name" title=""><i>Франклин Томас</i></a>
# <a data-edit="/admin/person/9498/edit" href="/person/donko-najdenov" itemprop="name">Донко Найденов</a>
# <a class="textlink" data-edit="/admin/text/39303/edit" href="/text/39303-direktivata-jansyn" itemprop="name" title=""><i>Директивата „Янсън“</i></a>
# <a data-edit="/admin/person/346/edit" href="/person/robert-ludlum" itemprop="name">Робърт Лъдлъм</a>
# <a class="textlink" data-edit="/admin/text/39302/edit" href="/text/39302-strah" itemprop="name" title=""><i>Страх</i></a>
# <a data-edit="/admin/person/198/edit" href="/person/l-ron-hubbard" itemprop="name">Л. Рон Хабърд</a>
# <a class="textlink" data-edit="/admin/text/39301/edit" href="/text/39301-motiv-za-ubijstvo" itemprop="name" title=""><i>Мотив за убийство</i></a>
# <a data-edit="/admin/person/8867/edit" href="/person/anne-holt" itemprop="name">Ане Холт</a>
# <a class="textlink" data-edit="/admin/text/39300/edit" href="/text/39300-slava-na-nashite-belezhiti-pioneri" itemprop="name" title=""><i>Слава на нашите бележити пионери</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39299/edit" href="/text/39299-naj-starata-istorija-na-sveta" itemprop="name" title=""><i>Най-старата история на света</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39298/edit" href="/text/39298-zhaduvam-nevinnost" itemprop="name" title=""><i>Жадувам невинност</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39297/edit" href="/text/39297-obitatelite-na-zemjata" itemprop="name" title=""><i>Обитателите на Земята</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39296/edit" href="/text/39296-govorja-za-geroizma" itemprop="name" title=""><i>Говоря за героизма</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39295/edit" href="/text/39295-na-kilimandzharo-vsichko-e-spokojno" itemprop="name" title=""><i>На Килиманджаро всичко е спокойно</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39294/edit" href="/text/39294-stenata" itemprop="name" title=""><i>Стената</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39293/edit" href="/text/39293-edna-istoricheska-stranitsa" itemprop="name" title=""><i>Една историческа страница</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39292/edit" href="/text/39292-grazhdaninyt-gylyb" itemprop="name" title=""><i>Гражданинът гълъб</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39291/edit" href="/text/39291-blagorodstvo-i-velichie" itemprop="name" title=""><i>Благородство и величие</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39290/edit" href="/text/39290-radostite-na-prirodata" itemprop="name" title=""><i>Радостите на природата</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39289/edit" href="/text/39289-falshifikat" itemprop="name" title=""><i>Фалшификат</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a class="textlink" data-edit="/admin/text/39288/edit" href="/text/39288-dekadans" itemprop="name" title=""><i>Декаданс</i></a>
# <a data-edit="/admin/person/8032/edit" href="/person/romain-gary" itemprop="name">Ромен Гари</a>
# <a href="/new/texts">Още нови произведения</a>
# <a href="//planet.chitanka.info/">От литературните блогове</a>
# <a href="https://zonkobg.blogspot.com/2018/03/blog-post_16.html">Спасителя - Ю Несбьо</a>
# <a href="https://1.bp.blogspot.com/-LBHc3cmEPvQ/WqtqZaHSSJI/AAAAAAAAGww/51VBQTp_rrYJbdBdsCyqkcEM4pmiq1uzwCLcBGAs/s1600/284.jpg" style="clear: left; float: left; margin-bottom: 1em; margin-right: 1em; text-align: justify;"><img border="0" height="200" src="https://1.bp.blogspot.com/-LBHc3cmEPvQ/WqtqZaHSSJI/AAAAAAAAGww/51VBQTp_rrYJbdBdsCyqkcEM4pmiq1uzwCLcBGAs/s200/284.jpg" width="124"/></a>
# <a href="//choveshkata.net/blog/?p=6521">Малкото четене: Текстове от Копнежа за растящо творчество</a>
# <a href="https://bibliotekata.wordpress.com/2018/03/13/otboi-v-polunosht/">Отбой в полунощ: Врагът е другаде</a>
# <a href="/search">Потърсено</a>
# <a href="/search?q=%D0%B4%D1%8F%D0%B2%D0%BE%D0%BB%D1%8A%D1%82+%D0%B2+%D1%82%D0%B5%D0%B1">дяволът в теб</a>
# <a href="/search?q=%D0%BB%D0%B8%D0%BD%D0%B8%D1%8F%D1%82%D0%B0+%D0%BD%D0%B0+%D0%B1%D0%BB%D1%8F%D0%BD%D0%BE%D0%B2%D0%B5">линията на блянове</a>
# <a href="/search?q=%D0%95%D0%BA%D0%B7%D0%BE%D1%82%D0%B8%D0%BA%D0%B0">Екзотика</a>
# <a href="/search?q=%D0%94%D1%83%D1%85%D0%BE%D0%B2%D0%B5">Духове</a>
# <a href="/search?q=winston">winston</a>
# <a href="/search?q=%D1%81%D0%BE%D0%B4%D0%B0">сода</a>
# <a href="/search?q=%D0%A4%D1%80%D0%B0%D0%BD%D0%BA+%D0%A5%D1%8A%D1%80%D0%B1%D1%8A%D1%80%D1%82">Франк Хърбърт</a>
# <a href="/search?q=%D0%B4%D0%B6%D0%BE%D0%BD+%D0%B3%D1%80%D0%B8%D1%88%D0%B0%D0%BC">джон гришам</a>
# <a href="/search?q=%D0%BB%D0%B8%D0%BD%D0%B4%D0%B0">линда</a>
# <a href="/search?q=%D0%90%D0%BD%D1%82%D1%8A%D0%BD%D0%B8+%D0%9A%D0%B0%D0%BF%D0%B5%D0%BB%D0%B0">Антъни Капела</a>
# <a href="/search?q=%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B8%D1%82%D0%B5+%D0%BD%D0%B0+%D0%B7%D0%BE%D1%80%D0%B0%D1%82%D0%B0">роботите на зората</a>
# <a href="/search?q=%D0%94%D0%96%D0%95%D0%A4%D0%A0%D0%98+%D0%90%D0%A0%D0%A7%D0%AA%D0%A0">ДЖЕФРИ АРЧЪР</a>
# <a href="/search?q=%D0%BC%D0%B0%D1%82%D1%8E+%D1%80%D0%B0%D0%B9%D0%BB%D0%B8">матю райли</a>
# <a href="/search?q=%D0%9C%D0%B0%D0%BB%D0%BA%D0%B0%D1%82%D0%B0+%D0%BF%D0%B8%D1%82%D0%BA%D0%B0">Малката питка</a>
# <a href="/search?q=%D0%98%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%8F+%D0%BD%D0%B0+%D0%B2%D1%80%D0%B5%D0%BC%D0%B5%D1%82%D0%BE">История на времето</a>
# <a href="/search?q=%D0%B0%D0%BD+%D0%BC%D0%B5%D0%B9">ан мей</a>
# <a href="/search?q=%D0%94%D0%BD%D0%B5%D0%B2%D0%BD%D0%B8%D1%86%D0%B8%D1%82%D0%B5">Дневниците</a>
# <a href="/search?q=%D0%91%D1%80%D0%B0%D0%BD%D0%B4%D1%8A%D0%BD">Брандън</a>
# <a href="/search?q=%D0%B4%D0%BE%D0%BD%D0%B5%D1%81%D0%B8+%D0%BC%D0%B8+%D0%B3%D0%BB%D0%B0%D0%B2%D0%B0%D1%82%D0%B0+%D0%BD%D0%B0+%D0%BF%D1%80%D0%B8%D0%BD%D1%86%D0%B0">донеси ми главата на принца</a>
# <a href="/search?q=%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B2+%D1%82%D0%B0%D0%BC%D0%B1%D1%83%D0%BA%D1%82%D1%83">остров тамбукту</a>
# <a href="/search?q=%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D1%8F">астрология</a>
# <a href="/search?q=%D0%91%D0%BE%D0%B9%D0%BD%D0%BE+%D0%BF%D0%BE%D0%BB%D0%B5+%D0%97%D0%B5%D0%BC%D1%8F">Бойно поле Земя</a>
# <a href="/search?q=%D0%B1%D0%B0%D1%80%D0%B1%D0%B0%D1%80%D0%B0+%D1%82%D0%B5%D0%B9%D0%BB%D1%8A%D1%80">барбара тейлър</a>
# <a href="/search?q=%D1%85%D0%BE%D0%B1">хоб</a>
# <a href="/search?q=rob">rob</a>
# <a href="/search?q=%D1%81%D1%83%D0%BD+%D0%B4%D0%B7%D1%8A">сун дзъ</a>
# <a href="/search?q=%D0%93%D1%80%D0%B0%D0%B4+%D0%BE%D1%82+%D0%BA%D0%BE%D1%81%D1%82%D0%B8">Град от кости</a>
# <a href="/search?q=%D0%B1%D0%BE%D1%82%D0%B5%D0%B2">ботев</a>
# <a href="/search?q=%D1%84%D0%BB%D0%BE%D0%B1%D0%B5%D1%80">флобер</a>
# <a href="/search?q=%D0%94%D0%BE%D0%B1%D1%80%D0%B8+%D0%9F%D0%BE%D0%BB%D0%B8%D1%87%D0%B1%D0%B8">Добри Поличби</a>
# <a href="/search?q=%D0%A1%D0%B8%D0%BD%D0%B8+%D0%B8%D0%BD">Сини ин</a>
# <a href="/search?q=%D0%B1%D0%B5%D0%B7%D0%BC%D1%8A%D0%BB%D0%B2%D0%BD%D0%B8%D1%8F%D1%82+%D0%B0%D0%BD%D0%B3%D0%B5%D0%BB">безмълвният ангел</a>
# <a href="/search?q=Kristi">Kristi</a>
# <a href="/search?q=%D0%97%D0%B0+%D1%87%D0%B5%D1%81%D1%82%D1%82%D0%B0+%D0%BD%D0%B0+%D0%BA%D1%80%D0%B0%D0%BB%D0%B8%D1%86%D0%B0%D1%82%D0%B0">За честта на кралицата</a>
# <a href="/search?q=%D0%95%D0%B3%D0%B8%D0%BF%D0%B5%D1%82">Египет</a>
# <a href="/search?q=%D0%AF%D0%B2%D0%BE%D1%80%D0%BE%D0%B2">Яворов</a>
# <a href="/search?q=%D1%80%D0%BE%D0%BC%D0%B0%D0%BD%D1%8A%D1%82+%D0%BD%D0%B0+%D1%8F%D0%B2%D0%BE%D1%80%D0%BE%D0%B2">романът на яворов</a>
# <a href="/search?q=%D0%B8%D0%B7%D0%BF%D0%B5%D0%BF%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8">изпепелени</a>
# <a href="/search?q=%D0%92%D0%B5%D1%89%D0%B5%D1%80%D1%8A%D1%82">Вещерът</a>
# <a href="/search?q=%D1%81%D1%83%D0%B2%D0%BE%D1%80%D0%BE%D0%B2">суворов</a>
# <a href="/search?q=%D1%85%D1%83%D0%BC%D0%BE%D1%80">хумор</a>
# <a href="/search?q=%D0%B3%D0%BE%D0%BB%D1%8F%D0%BC+%D0%B3%D0%B0%D0%BB%D1%8C%D0%BE%D0%B2%D0%BD%D0%B8%D0%BA">голям гальовник</a>
# <a href="/search?q=%D0%B5%D1%80%D0%B0%D0%B3%D0%BE%D0%BD">ерагон</a>
# <a href="/search?q=%D0%B8%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%8F+%D0%BD%D0%B0+%D0%91%D0%AA%D0%9B%D0%93%D0%90%D0%A0%D0%98%D0%AF">история на БЪЛГАРИЯ</a>
# <a href="/search?q=%D0%98%D0%B3%D1%80%D0%B0+%D0%BD%D0%B0+%D1%82%D1%80%D0%BE%D0%BD%D0%BE%D0%B2%D0%B5">Игра на тронове</a>
# <a href="/search?q=%D0%9E%D0%BB%D0%B4+">Олд </a>
# <a href="/search?q=%D0%A0%D0%B8%D0%B1%D0%B0%D1%82%D0%B0+%D0%B8+%D0%BF%D1%80%D1%8A%D1%81%D1%82%D0%B5%D0%BD%D1%8A%D1%82">Рибата и пръстенът</a>
# <a href="/search?q=%D0%9E%D0%BA%D0%BE+%D0%B7%D0%B0+%D0%BE%D0%BA%D0%BE">Око за око</a>
# <a href="/search?q=%D0%B8%D0%B7%D0%B2%D1%8A%D0%BD+%D0%B7%D0%B0%D0%BA%D0%BE%D0%BD%D0%B0">извън закона</a>
# <a href="/search?q=%D0%B7%D0%B0%D0%B1%D0%B0%D0%B2%D0%BD%D0%B0+%D0%B1%D0%B8%D0%B1%D0%BB%D0%B8%D1%8F">забавна библия</a>
# <a href="/texts/comments">Читателите казват</a>
# <a class="textlink" data-edit="/admin/text/39305/edit" href="/text/39305-detsata-ot-ulitsa-trjaskadzhijska" itemprop="name" title=""><i>Децата от улица „Тряскаджийска“</i></a>
# <a data-edit="/admin/person/33/edit" href="/person/astrid-lindgren" itemprop="name">Астрид Линдгрен</a>
# <a class="js" href="/text/39305/comments?replyto=30545#e30545" onclick="return initReply(30545)" title="Отговор на коментара">Отговор</a>
# <a href="/text/39305/comments" title="Всички коментари за произведението">Всички коментари</a>
# <a class="user" href="/user/yulmana">yulmana</a>
# <a class="textlink" data-edit="/admin/text/13596/edit" href="/text/13596-goreshto-utro" itemprop="name" title=""><i>Горещо утро</i></a>
# <a data-edit="/admin/person/2297/edit" href="/person/sandra-brown" itemprop="name">Сандра Браун</a>
# <a class="js" href="/text/13596/comments?replyto=30544#e30544" onclick="return initReply(30544)" title="Отговор на коментара">Отговор</a>
# <a href="/text/13596/comments" title="Всички коментари за произведението">Всички коментари</a>
# <a class="user" href="/user/%D0%95%D0%BC%D0%B860">Еми60</a>
# <a class="textlink" data-edit="/admin/text/38605/edit" href="/text/38605-klinika-v-sredata-na-noshtta" itemprop="name" title=""><i>Клиника в средата на нощта</i></a>
# <a data-edit="/admin/person/9668/edit" href="/person/dimityr-tsolov" itemprop="name">Димитър Цолов</a>
# <a class="js" href="/text/38605/comments?replyto=30543#e30543" onclick="return initReply(30543)" title="Отговор на коментара">Отговор</a>
# <a href="/text/38605/comments" title="Всички коментари за произведението">Всички коментари</a>
# <a class="user" href="/user/morski%20pras">morski pras</a>
# <a class="textlink" data-edit="/admin/text/26976/edit" href="/text/26976-chudnite-prikljuchenija-na-baron-mjunhauzen" itemprop="name" title=""><i>Чудните приключения на Барон Мюнхаузен</i></a>
# <a data-edit="/admin/person/281/edit" href="/person/rudolf-erich-raspe" itemprop="name">Рудолф Ерих Распе</a>
# <a class="js" href="/text/26976/comments?replyto=30542#e30542" onclick="return initReply(30542)" title="Отговор на коментара">Отговор</a>
# <a href="/text/26976/comments" title="Всички коментари за произведението">Всички коментари</a>
# <a class="user" href="/user/Annonnymous">Annonnymous</a>
# <a class="textlink" data-edit="/admin/text/5955/edit" href="/text/5955-az-sym-legenda" itemprop="name" title=""><i>Аз съм легенда</i></a>
# <a data-edit="/admin/person/1431/edit" href="/person/richard-matheson" itemprop="name">Ричард Матисън</a>
# <a class="js" href="/text/5955/comments?replyto=30541#e30541" onclick="return initReply(30541)" title="Отговор на коментара">Отговор</a>
# <a href="/text/5955/comments" title="Всички коментари за произведението">Всички коментари</a>
# <a class="user" href="/user/moketa">moketa</a>
# <a href="//forum.chitanka.info">От форума</a>
# <a href="https://forum.chitanka.info/viewtopic.php?t=5868&amp;p=25888#p25888">Съобщения за грешки из сайта • Re: Грешка "500 Internet Server Error"</a>
# <a href="https://forum.chitanka.info/memberlist.php?mode=viewprofile&amp;u=31778">Берлиоз</a>
# <a href="https://forum.chitanka.info/viewtopic.php?t=5866&amp;p=25887#p25887">Как се казваше?… • Re: Търся трилър</a>
# <a href="https://forum.chitanka.info/memberlist.php?mode=viewprofile&amp;u=36558">gsmoskov</a>
# <a href="https://forum.chitanka.info/viewtopic.php?t=5868&amp;p=25886#p25886">Съобщения за грешки из сайта • Грешка "500 Internet Server Error"</a>
# <a href="https://forum.chitanka.info/viewtopic.php?t=5867&amp;p=25885#p25885">Анонси за нови произведения • И „Приказки за Юнаци и злодеи: втори“ в ЧоБи</a>
# <a class="postlink" href="//choveshkata.net/blog/?page_id=13">поредица „Човешката библиотека“</a>
# <a class="postlink" href="//choveshkata.net/blog/?p=6602">„Приказки за Юнаци и злодеи: втори“</a>
# <a class="postlink" href="https://docs.google.com/forms/d/1Teui-YqZsiXVWJVABu0cSiyki6lTPHRWIZSiD6EQfGY/viewform">да им подарите сборника</a>
# <a class="postlink" href="//choveshkata.net/blog/?page_id=6470">„Приказки за Юнаци и злодеи: първи“</a>
# <a class="postlink" href="//choveshkata.net/blog/?page_id=5055">„Приказки за Юнаци и злодеи: Промяна“</a>
# <a href="https://forum.chitanka.info/memberlist.php?mode=viewprofile&amp;u=3021">Кал</a>
# <a href="https://forum.chitanka.info/viewtopic.php?t=5866&amp;p=25884#p25884">Как се казваше?… • Търся трилър</a>
# <a href="https://forum.chitanka.info/memberlist.php?mode=viewprofile&amp;u=35161">Zakk</a>
# <a href="/login"><span class="fa fa-sign-in"></span> Вход</a>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="fa fa-caret-down"></span>
# </a>
# <a href="/register"><span class="fa fa-user"></span> Регистрация</a>
# <a href="/about">За Моята библиотека</a>
# <a href="/rules">Правила</a>
# <a href="/faq">Въпроси и отговори</a>
# <a href="/feedback" title="Връзка с администраторите на библиотеката">Връзка с екипа</a>
# <a href="/donations">Дарения</a>
# <a href="/api">API</a>
# <a href="#main-content" id="goto-top-link" title="Към началото на страницата"><span class="fa fa-chevron-circle-up"></span><span class="sr-only">Към началото на страницата</span></a>
